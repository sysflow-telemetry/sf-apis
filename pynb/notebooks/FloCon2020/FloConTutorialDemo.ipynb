# %% [markdown]
# # SysFlow FloCon 2020 Tutorial Demo
# Tutorial demo session presented at FloCon 2020. Please check [abstract and presentation slides](https://flocon2020.sched.com/event/VPW3/sysflow-scalable-system-telemetry-for-improved-security-analytics) at the conference website.

# %%
# sysflow libraries
from sysflow.reader import FlattenedSFReader
from sysflow.formatter import SFFormatter

# %% [markdown]
# ## Data Exploration

# %%
# additional libraries
import numpy as np
import pandas as pd
pd.set_option('display.max_colwidth', 75)

# %%
# sysflow trace path and selected attributes to display
trace = '../../data/objectstore/download.sf'
cols=['ts_uts', 'endts_uts', 'type', 'opflags', 'proc.pid', 'proc.tid', 'proc.exe', 'res', 'flow.rbytes', 'flow.wbytes', 'flow.rops', 'flow.wops', 'container.imageid']

# %%
# read sysfow records into a pandas dataframe
reader = FlattenedSFReader(trace)
formatter = SFFormatter(reader)
df = formatter.toDataframe(fields=cols)
df.shape
# Out:
# (220, 13)

# %%
# display a few records filtering file and network flows with READ/RECEIVE operations
df[(df.type.isin(['FF','NF'])) & (df.opflags.str.contains('R'))].tail(20)
# Out:
#                   ts_uts     endts_uts type      opflags  proc.pid  proc.tid  \
# 199  1555013930201923664  1.555014e+18   FF  O   R   C       13144     13144
# 200  1555013930197179649  1.555014e+18   NF   A WR    T      13144     13179
# 201  1555013930200065133  1.555014e+18   NF     WR    T      13144     13185
# 202  1555013930198104699  1.555014e+18   NF     WR   C       13144     13144
# 203  1555013930203486343  1.555014e+18   FF  O   R   C       13144     13179
# 204  1555013930203635386  1.555014e+18   FF  O   R   C       13144     13179
# 205  1555013930203603871  1.555014e+18   FF  O   R   C       13144     13179
# 207  1555013930205607500  1.555014e+18   FF  O   R   C       13144     13144
# 208  1555013930206704188  1.555014e+18   FF  O   R   C       13144     13179
# 209  1555013930207555855  1.555014e+18   FF  O   R   C       13144     13144
# 210  1555013930207708483  1.555014e+18   FF  O   R   C       13144     13144
# 211  1555013930207676814  1.555014e+18   FF  O   R   C       13144     13144
# 212  1555013930203070983  1.555014e+18   NF   A  R    T      13144     13185
# 213  1555013930203867227  1.555014e+18   NF     WR    T      13144     13179
# 214  1555013930205751818  1.555014e+18   NF     WR   C       13144     13144
# 215  1555013930209183475  1.555014e+18   FF  O   R   C       13144     13185
# 216  1555013930209329015  1.555014e+18   FF  O   R   C       13144     13185
# 217  1555013930209297099  1.555014e+18   FF  O   R   C       13144     13185
# 218  1555013930208803615  1.555014e+18   NF   A  R    T      13144     13179
# 219  1555013930209523058  1.555014e+18   NF     WR   C       13144     13185
#
#            proc.exe                                                    res  \
# 199  /usr/bin/minio   /data/.minio.sys/buckets/play/mon.1548966016/fs.json
# 200  /usr/bin/minio                       172.17.0.5:52940-172.17.0.4:9000
# 201  /usr/bin/minio                       172.17.0.5:52940-172.17.0.4:9000
# 202  /usr/bin/minio                       172.17.0.5:52940-172.17.0.4:9000
# 203  /usr/bin/minio   /data/.minio.sys/buckets/play/mon.1548966016/fs.json
# 204  /usr/bin/minio                              /data/play/mon.1548966016
# 205  /usr/bin/minio   /data/.minio.sys/buckets/play/mon.1548966016/fs.json
# 207  /usr/bin/minio  /data/.minio.sys/buckets/play/tcpclientserver/fs.json
# 208  /usr/bin/minio  /data/.minio.sys/buckets/play/tcpclientserver/fs.json
# 209  /usr/bin/minio  /data/.minio.sys/buckets/play/tcpclientserver/fs.json
# 210  /usr/bin/minio                             /data/play/tcpclientserver
# 211  /usr/bin/minio  /data/.minio.sys/buckets/play/tcpclientserver/fs.json
# 212  /usr/bin/minio                       172.17.0.5:52942-172.17.0.4:9000
# 213  /usr/bin/minio                       172.17.0.5:52942-172.17.0.4:9000
# 214  /usr/bin/minio                       172.17.0.5:52942-172.17.0.4:9000
# 215  /usr/bin/minio  /data/.minio.sys/buckets/play/tcpclientserver/fs.json
# 216  /usr/bin/minio                             /data/play/tcpclientserver
# 217  /usr/bin/minio  /data/.minio.sys/buckets/play/tcpclientserver/fs.json
# 218  /usr/bin/minio                       172.17.0.5:52944-172.17.0.4:9000
# 219  /usr/bin/minio                       172.17.0.5:52944-172.17.0.4:9000
#
#      flow.rbytes  flow.wbytes  flow.rops  flow.wops  \
# 199        168.0          0.0        1.0        0.0
# 200       1053.0        421.0        4.0        1.0
# 201        963.0        972.0        4.0        2.0
# 202          0.0      21995.0        1.0        4.0
# 203        168.0          0.0        1.0        0.0
# 204      10885.0          0.0        1.0        0.0
# 205        168.0          0.0        1.0        0.0
# 207        168.0          0.0        1.0        0.0
# 208        168.0          0.0        1.0        0.0
# 209        168.0          0.0        1.0        0.0
# 210      12571.0          0.0        1.0        0.0
# 211        168.0          0.0        1.0        0.0
# 212       1537.0          0.0        6.0        0.0
# 213        482.0      11727.0        2.0        3.0
# 214          0.0      13967.0        1.0        4.0
# 215        168.0          0.0        1.0        0.0
# 216      12571.0          0.0        1.0        0.0
# 217        168.0          0.0        1.0        0.0
# 218        537.0          0.0        2.0        0.0
# 219          0.0      12992.0        1.0        2.0
#
#                                                     container.imageid
# 199  3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718
# 200  3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718
# 201  3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718
# 202  3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718
# 203  3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718
# 204  3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718
# 205  3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718
# 207  3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718
# 208  3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718
# 209  3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718
# 210  3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718
# 211  3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718
# 212  3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718
# 213  3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718
# 214  3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718
# 215  3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718
# 216  3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718
# 217  3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718
# 218  3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718
# 219  3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718

# %%
# display a few records
flows = df[(df.type.isin(['FF','NF']))]
flows[['flow.rbytes', 'flow.wbytes', 'flow.rops', 'flow.wops']].astype('int32').describe()
# Out:
#         flow.rbytes   flow.wbytes   flow.rops   flow.wops
# count    197.000000    197.000000  197.000000  197.000000
# mean    2199.736041   2092.619289    1.350254    0.416244
# std     6480.210999   7720.554313    1.946782    1.211905
# min        0.000000      0.000000    0.000000    0.000000
# 25%        0.000000      0.000000    1.000000    0.000000
# 50%      168.000000      0.000000    1.000000    0.000000
# 75%      517.000000      0.000000    1.000000    0.000000
# max    34283.000000  64206.000000   20.000000    8.000000

# %%
import matplotlib.pylab as plt
import matplotlib.dates as mdates
ax = flows[['ts_uts', 'flow.rbytes', 'flow.wbytes']].plot.bar(x='ts_uts', y=['flow.rbytes','flow.wbytes'], rot=45, figsize=(20,5))
ax.xaxis.set_major_locator(mdates.AutoDateLocator())
plt.gcf().autofmt_xdate()
plt.show()

# %% [markdown]
# ## Data Conversion

# %%
# Read and dump sysflow records as JSON file
import json
reader = FlattenedSFReader(trace)
formatter = SFFormatter(reader)
formatter.toJsonFile(path='/tmp/json')

# %%
# Load and print sysflow records as JSON
with open('/tmp/json') as jsonfile:
    js =json.load(jsonfile)
print(json.dumps(js, indent=2, sort_keys=True))
# Out:
# [
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "",
#     "endts_uts": null,
#     "file": {
#       "fd": "",
#       "newpath": "",
#       "openflags": "",
#       "path": "",
#       "type": ""
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": null,
#       "rops": null,
#       "wbytes": null,
#       "wops": null
#     },
#     "net": {
#       "dip": "",
#       "dport": null,
#       "proto": "",
#       "sip": "",
#       "sport": null
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "CLONE",
#     "opflags_bitmap": 1,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "",
#       "createts": "",
#       "entry": "",
#       "exe": "",
#       "gid": null,
#       "group": "",
#       "pid": null,
#       "tty": "",
#       "uid": null,
#       "user": ""
#     },
#     "proc": {
#       "args": "init",
#       "createts": 0,
#       "entry": "",
#       "exe": "docker-runc",
#       "gid": -1,
#       "group": "",
#       "pid": 17059,
#       "tid": 17061,
#       "tty": false,
#       "uid": -1,
#       "user": ""
#     },
#     "res": "",
#     "ret": 0,
#     "schema": 1000,
#     "state": "CREATED",
#     "ts": "2019-04-11T20:18:48.557415",
#     "ts_uts": 1555013928557415261,
#     "type": "PE",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "",
#     "endts_uts": null,
#     "file": {
#       "fd": "",
#       "newpath": "",
#       "openflags": "",
#       "path": "",
#       "type": ""
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": null,
#       "rops": null,
#       "wbytes": null,
#       "wops": null
#     },
#     "net": {
#       "dip": "",
#       "dport": null,
#       "proto": "",
#       "sip": "",
#       "sport": null
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "CLONE",
#     "opflags_bitmap": 1,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "",
#       "createts": "",
#       "entry": "",
#       "exe": "",
#       "gid": null,
#       "group": "",
#       "pid": null,
#       "tty": "",
#       "uid": null,
#       "user": ""
#     },
#     "proc": {
#       "args": "init",
#       "createts": 0,
#       "entry": "",
#       "exe": "docker-runc",
#       "gid": -1,
#       "group": "",
#       "pid": 17059,
#       "tid": 17060,
#       "tty": false,
#       "uid": -1,
#       "user": ""
#     },
#     "res": "",
#     "ret": 0,
#     "schema": 1000,
#     "state": "CREATED",
#     "ts": "2019-04-11T20:18:48.558260",
#     "ts_uts": 1555013928558260218,
#     "type": "PE",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "",
#     "endts_uts": null,
#     "file": {
#       "fd": "",
#       "newpath": "",
#       "openflags": "",
#       "path": "",
#       "type": ""
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": null,
#       "rops": null,
#       "wbytes": null,
#       "wops": null
#     },
#     "net": {
#       "dip": "",
#       "dport": null,
#       "proto": "",
#       "sip": "",
#       "sport": null
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "CLONE",
#     "opflags_bitmap": 1,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "",
#       "createts": "",
#       "entry": "",
#       "exe": "",
#       "gid": null,
#       "group": "",
#       "pid": null,
#       "tty": "",
#       "uid": null,
#       "user": ""
#     },
#     "proc": {
#       "args": "init",
#       "createts": 0,
#       "entry": "",
#       "exe": "docker-runc",
#       "gid": -1,
#       "group": "",
#       "pid": 17059,
#       "tid": 17062,
#       "tty": false,
#       "uid": -1,
#       "user": ""
#     },
#     "res": "",
#     "ret": 0,
#     "schema": 1000,
#     "state": "CREATED",
#     "ts": "2019-04-11T20:18:48.558287",
#     "ts_uts": 1555013928558287176,
#     "type": "PE",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "",
#     "endts_uts": null,
#     "file": {
#       "fd": "",
#       "newpath": "",
#       "openflags": "",
#       "path": "",
#       "type": ""
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": null,
#       "rops": null,
#       "wbytes": null,
#       "wops": null
#     },
#     "net": {
#       "dip": "",
#       "dport": null,
#       "proto": "",
#       "sip": "",
#       "sport": null
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "EXIT",
#     "opflags_bitmap": 4,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "",
#       "createts": "",
#       "entry": "",
#       "exe": "",
#       "gid": null,
#       "group": "",
#       "pid": null,
#       "tty": "",
#       "uid": null,
#       "user": ""
#     },
#     "proc": {
#       "args": "init",
#       "createts": 0,
#       "entry": "",
#       "exe": "docker-runc",
#       "gid": -1,
#       "group": "",
#       "pid": 17059,
#       "tid": 17060,
#       "tty": false,
#       "uid": -1,
#       "user": ""
#     },
#     "res": "",
#     "ret": 0,
#     "schema": 1000,
#     "state": "CREATED",
#     "ts": "2019-04-11T20:18:48.586449",
#     "ts_uts": 1555013928586448628,
#     "type": "PE",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "",
#     "endts_uts": null,
#     "file": {
#       "fd": "",
#       "newpath": "",
#       "openflags": "",
#       "path": "",
#       "type": ""
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": null,
#       "rops": null,
#       "wbytes": null,
#       "wops": null
#     },
#     "net": {
#       "dip": "",
#       "dport": null,
#       "proto": "",
#       "sip": "",
#       "sport": null
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "EXIT",
#     "opflags_bitmap": 4,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "",
#       "createts": "",
#       "entry": "",
#       "exe": "",
#       "gid": null,
#       "group": "",
#       "pid": null,
#       "tty": "",
#       "uid": null,
#       "user": ""
#     },
#     "proc": {
#       "args": "init",
#       "createts": 0,
#       "entry": "",
#       "exe": "docker-runc",
#       "gid": -1,
#       "group": "",
#       "pid": 17059,
#       "tid": 17061,
#       "tty": false,
#       "uid": -1,
#       "user": ""
#     },
#     "res": "",
#     "ret": 0,
#     "schema": 1000,
#     "state": "CREATED",
#     "ts": "2019-04-11T20:18:48.586463",
#     "ts_uts": 1555013928586462941,
#     "type": "PE",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "",
#     "endts_uts": null,
#     "file": {
#       "fd": "",
#       "newpath": "",
#       "openflags": "",
#       "path": "",
#       "type": ""
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": null,
#       "rops": null,
#       "wbytes": null,
#       "wops": null
#     },
#     "net": {
#       "dip": "",
#       "dport": null,
#       "proto": "",
#       "sip": "",
#       "sport": null
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "EXIT",
#     "opflags_bitmap": 4,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "",
#       "createts": "",
#       "entry": "",
#       "exe": "",
#       "gid": null,
#       "group": "",
#       "pid": null,
#       "tty": "",
#       "uid": null,
#       "user": ""
#     },
#     "proc": {
#       "args": "init",
#       "createts": 0,
#       "entry": "",
#       "exe": "docker-runc",
#       "gid": -1,
#       "group": "",
#       "pid": 17059,
#       "tid": 17062,
#       "tty": false,
#       "uid": -1,
#       "user": ""
#     },
#     "res": "",
#     "ret": 0,
#     "schema": 1000,
#     "state": "CREATED",
#     "ts": "2019-04-11T20:18:48.586470",
#     "ts_uts": 1555013928586469785,
#     "type": "PE",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "",
#     "endts_uts": null,
#     "file": {
#       "fd": "",
#       "newpath": "",
#       "openflags": "",
#       "path": "",
#       "type": ""
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": null,
#       "rops": null,
#       "wbytes": null,
#       "wops": null
#     },
#     "net": {
#       "dip": "",
#       "dport": null,
#       "proto": "",
#       "sip": "",
#       "sport": null
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "EXEC",
#     "opflags_bitmap": 2,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "",
#       "createts": "",
#       "entry": "",
#       "exe": "",
#       "gid": null,
#       "group": "",
#       "pid": null,
#       "tty": "",
#       "uid": null,
#       "user": ""
#     },
#     "proc": {
#       "args": "-c /usr/bin/healthcheck.sh",
#       "createts": 0,
#       "entry": "",
#       "exe": "/bin/dash",
#       "gid": -1,
#       "group": "",
#       "pid": 17059,
#       "tid": 17059,
#       "tty": false,
#       "uid": -1,
#       "user": ""
#     },
#     "res": "",
#     "ret": 0,
#     "schema": 1000,
#     "state": "MODIFIED",
#     "ts": "2019-04-11T20:18:48.586900",
#     "ts_uts": 1555013928586900387,
#     "type": "PE",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "",
#     "endts_uts": null,
#     "file": {
#       "fd": "",
#       "newpath": "",
#       "openflags": "",
#       "path": "",
#       "type": ""
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": null,
#       "rops": null,
#       "wbytes": null,
#       "wops": null
#     },
#     "net": {
#       "dip": "",
#       "dport": null,
#       "proto": "",
#       "sip": "",
#       "sport": null
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "EXEC",
#     "opflags_bitmap": 2,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "-c /usr/bin/healthcheck.sh",
#       "createts": 0,
#       "entry": "",
#       "exe": "/bin/dash",
#       "gid": -1,
#       "group": "",
#       "pid": 17059,
#       "tty": false,
#       "uid": -1,
#       "user": ""
#     },
#     "proc": {
#       "args": "/usr/bin/healthcheck.sh",
#       "createts": 1555013928590063189,
#       "entry": "",
#       "exe": "/usr/bin/healthcheck.sh",
#       "gid": 0,
#       "group": "root",
#       "pid": 17063,
#       "tid": 17063,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "res": "",
#     "ret": 0,
#     "schema": 1000,
#     "state": "CREATED",
#     "ts": "2019-04-11T20:18:48.590213",
#     "ts_uts": 1555013928590212928,
#     "type": "PE",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "2019-04-11T20:18:48.590440",
#     "endts_uts": 1555013928590439695,
#     "file": {
#       "fd": 3,
#       "newpath": "",
#       "openflags": 1,
#       "path": "/usr/bin/healthcheck.sh",
#       "type": "f"
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": 0,
#       "rops": 0,
#       "wbytes": 0,
#       "wops": 0
#     },
#     "net": {
#       "dip": "",
#       "dport": null,
#       "proto": "",
#       "sip": "",
#       "sport": null
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "O       C  ",
#     "opflags_bitmap": 1152,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "-c /usr/bin/healthcheck.sh",
#       "createts": 0,
#       "entry": "",
#       "exe": "/bin/dash",
#       "gid": -1,
#       "group": "",
#       "pid": 17059,
#       "tty": false,
#       "uid": -1,
#       "user": ""
#     },
#     "proc": {
#       "args": "/usr/bin/healthcheck.sh",
#       "createts": 1555013928590063189,
#       "entry": "",
#       "exe": "/usr/bin/healthcheck.sh",
#       "gid": 0,
#       "group": "root",
#       "pid": 17063,
#       "tid": 17063,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "res": "/usr/bin/healthcheck.sh",
#     "ret": null,
#     "schema": 1000,
#     "state": "CREATED",
#     "ts": "2019-04-11T20:18:48.590435",
#     "ts_uts": 1555013928590435074,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "2019-04-11T20:18:48.591278",
#     "endts_uts": 1555013928591278246,
#     "file": {
#       "fd": 4,
#       "newpath": "",
#       "openflags": 0,
#       "path": "",
#       "type": "p"
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": 0,
#       "rops": 0,
#       "wbytes": 0,
#       "wops": 0
#     },
#     "net": {
#       "dip": "",
#       "dport": null,
#       "proto": "",
#       "sip": "",
#       "sport": null
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "        C  ",
#     "opflags_bitmap": 1024,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "-c /usr/bin/healthcheck.sh",
#       "createts": 0,
#       "entry": "",
#       "exe": "/bin/dash",
#       "gid": -1,
#       "group": "",
#       "pid": 17059,
#       "tty": false,
#       "uid": -1,
#       "user": ""
#     },
#     "proc": {
#       "args": "/usr/bin/healthcheck.sh",
#       "createts": 1555013928590063189,
#       "entry": "",
#       "exe": "/usr/bin/healthcheck.sh",
#       "gid": 0,
#       "group": "root",
#       "pid": 17063,
#       "tid": 17063,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "res": "",
#     "ret": null,
#     "schema": 1000,
#     "state": "CREATED",
#     "ts": "2019-04-11T20:18:48.591278",
#     "ts_uts": 1555013928591278246,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "2019-04-11T20:18:48.591327",
#     "endts_uts": 1555013928591327433,
#     "file": {
#       "fd": 10,
#       "newpath": "",
#       "openflags": 0,
#       "path": "/usr/bin/healthcheck.sh",
#       "type": "f"
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": 0,
#       "rops": 0,
#       "wbytes": 0,
#       "wops": 0
#     },
#     "net": {
#       "dip": "",
#       "dport": null,
#       "proto": "",
#       "sip": "",
#       "sport": null
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "        C  ",
#     "opflags_bitmap": 1024,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "/usr/bin/healthcheck.sh",
#       "createts": 1555013928590063189,
#       "entry": "",
#       "exe": "/usr/bin/healthcheck.sh",
#       "gid": 0,
#       "group": "root",
#       "pid": 17063,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "proc": {
#       "args": "/usr/bin/healthcheck.sh",
#       "createts": 1555013928591289749,
#       "entry": "",
#       "exe": "/usr/bin/healthcheck.sh",
#       "gid": 0,
#       "group": "root",
#       "pid": 17064,
#       "tid": 17064,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "res": "/usr/bin/healthcheck.sh",
#     "ret": null,
#     "schema": 1000,
#     "state": "REUP",
#     "ts": "2019-04-11T20:18:48.591327",
#     "ts_uts": 1555013928591327433,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "2019-04-11T20:18:48.591332",
#     "endts_uts": 1555013928591331723,
#     "file": {
#       "fd": 3,
#       "newpath": "",
#       "openflags": 0,
#       "path": "",
#       "type": "p"
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": 0,
#       "rops": 0,
#       "wbytes": 0,
#       "wops": 0
#     },
#     "net": {
#       "dip": "",
#       "dport": null,
#       "proto": "",
#       "sip": "",
#       "sport": null
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "        C  ",
#     "opflags_bitmap": 1024,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "/usr/bin/healthcheck.sh",
#       "createts": 1555013928590063189,
#       "entry": "",
#       "exe": "/usr/bin/healthcheck.sh",
#       "gid": 0,
#       "group": "root",
#       "pid": 17063,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "proc": {
#       "args": "/usr/bin/healthcheck.sh",
#       "createts": 1555013928591289749,
#       "entry": "",
#       "exe": "/usr/bin/healthcheck.sh",
#       "gid": 0,
#       "group": "root",
#       "pid": 17064,
#       "tid": 17064,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "res": "",
#     "ret": null,
#     "schema": 1000,
#     "state": "REUP",
#     "ts": "2019-04-11T20:18:48.591332",
#     "ts_uts": 1555013928591331723,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "2019-04-11T20:18:48.591439",
#     "endts_uts": 1555013928591438926,
#     "file": {
#       "fd": 4,
#       "newpath": "",
#       "openflags": 0,
#       "path": "",
#       "type": "p"
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": 0,
#       "rops": 0,
#       "wbytes": 0,
#       "wops": 0
#     },
#     "net": {
#       "dip": "",
#       "dport": null,
#       "proto": "",
#       "sip": "",
#       "sport": null
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "        C  ",
#     "opflags_bitmap": 1024,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "/usr/bin/healthcheck.sh",
#       "createts": 1555013928590063189,
#       "entry": "",
#       "exe": "/usr/bin/healthcheck.sh",
#       "gid": 0,
#       "group": "root",
#       "pid": 17063,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "proc": {
#       "args": "/usr/bin/healthcheck.sh",
#       "createts": 1555013928591289749,
#       "entry": "",
#       "exe": "/usr/bin/healthcheck.sh",
#       "gid": 0,
#       "group": "root",
#       "pid": 17064,
#       "tid": 17064,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "res": "",
#     "ret": null,
#     "schema": 1000,
#     "state": "REUP",
#     "ts": "2019-04-11T20:18:48.591439",
#     "ts_uts": 1555013928591438926,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "2019-04-11T20:18:48.591520",
#     "endts_uts": 1555013928591520201,
#     "file": {
#       "fd": 3,
#       "newpath": "",
#       "openflags": 0,
#       "path": "",
#       "type": "p"
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": 0,
#       "rops": 0,
#       "wbytes": 0,
#       "wops": 0
#     },
#     "net": {
#       "dip": "",
#       "dport": null,
#       "proto": "",
#       "sip": "",
#       "sport": null
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "        C  ",
#     "opflags_bitmap": 1024,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "/usr/bin/healthcheck.sh",
#       "createts": 1555013928590063189,
#       "entry": "",
#       "exe": "/usr/bin/healthcheck.sh",
#       "gid": 0,
#       "group": "root",
#       "pid": 17063,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "proc": {
#       "args": "/usr/bin/healthcheck.sh",
#       "createts": 1555013928591289749,
#       "entry": "",
#       "exe": "/usr/bin/healthcheck.sh",
#       "gid": 0,
#       "group": "root",
#       "pid": 17064,
#       "tid": 17064,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "res": "",
#     "ret": null,
#     "schema": 1000,
#     "state": "REUP",
#     "ts": "2019-04-11T20:18:48.591520",
#     "ts_uts": 1555013928591520201,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "",
#     "endts_uts": null,
#     "file": {
#       "fd": "",
#       "newpath": "",
#       "openflags": "",
#       "path": "",
#       "type": ""
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": null,
#       "rops": null,
#       "wbytes": null,
#       "wops": null
#     },
#     "net": {
#       "dip": "",
#       "dport": null,
#       "proto": "",
#       "sip": "",
#       "sport": null
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "EXEC",
#     "opflags_bitmap": 2,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "/usr/bin/healthcheck.sh",
#       "createts": 1555013928591289749,
#       "entry": "",
#       "exe": "/usr/bin/healthcheck.sh",
#       "gid": 0,
#       "group": "root",
#       "pid": 17064,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "proc": {
#       "args": " /(.*\\/minio)/ { gsub(\":::\",\"127.0.0.1:\",$4); print $4}",
#       "createts": 1555013928595224518,
#       "entry": "",
#       "exe": "/usr/bin/awk",
#       "gid": 0,
#       "group": "root",
#       "pid": 17066,
#       "tid": 17066,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "res": "",
#     "ret": 0,
#     "schema": 1000,
#     "state": "CREATED",
#     "ts": "2019-04-11T20:18:48.596461",
#     "ts_uts": 1555013928596460518,
#     "type": "PE",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "2019-04-11T20:18:48.596799",
#     "endts_uts": 1555013928596799385,
#     "file": {
#       "fd": 3,
#       "newpath": "",
#       "openflags": 262,
#       "path": "/dev/null",
#       "type": "f"
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": 0,
#       "rops": 0,
#       "wbytes": 0,
#       "wops": 0
#     },
#     "net": {
#       "dip": "",
#       "dport": null,
#       "proto": "",
#       "sip": "",
#       "sport": null
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "O       C  ",
#     "opflags_bitmap": 1152,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "/usr/bin/healthcheck.sh",
#       "createts": 1555013928591289749,
#       "entry": "",
#       "exe": "/usr/bin/healthcheck.sh",
#       "gid": 0,
#       "group": "root",
#       "pid": 17064,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "proc": {
#       "args": "/usr/bin/healthcheck.sh",
#       "createts": 1555013928596730857,
#       "entry": "",
#       "exe": "/usr/bin/healthcheck.sh",
#       "gid": 0,
#       "group": "root",
#       "pid": 17065,
#       "tid": 17065,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "res": "/dev/null",
#     "ret": null,
#     "schema": 1000,
#     "state": "REUP",
#     "ts": "2019-04-11T20:18:48.596793",
#     "ts_uts": 1555013928596793282,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "",
#     "endts_uts": null,
#     "file": {
#       "fd": "",
#       "newpath": "",
#       "openflags": "",
#       "path": "",
#       "type": ""
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": null,
#       "rops": null,
#       "wbytes": null,
#       "wops": null
#     },
#     "net": {
#       "dip": "",
#       "dport": null,
#       "proto": "",
#       "sip": "",
#       "sport": null
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "EXEC",
#     "opflags_bitmap": 2,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "/usr/bin/healthcheck.sh",
#       "createts": 1555013928591289749,
#       "entry": "",
#       "exe": "/usr/bin/healthcheck.sh",
#       "gid": 0,
#       "group": "root",
#       "pid": 17064,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "proc": {
#       "args": "-nplt",
#       "createts": 1555013928596730857,
#       "entry": "",
#       "exe": "/bin/netstat",
#       "gid": 0,
#       "group": "root",
#       "pid": 17065,
#       "tid": 17065,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "res": "",
#     "ret": 0,
#     "schema": 1000,
#     "state": "MODIFIED",
#     "ts": "2019-04-11T20:18:48.596908",
#     "ts_uts": 1555013928596907661,
#     "type": "PE",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "2019-04-11T20:18:48.597466",
#     "endts_uts": 1555013928597466279,
#     "file": {
#       "fd": 4,
#       "newpath": "",
#       "openflags": 1,
#       "path": "/proc/1/cmdline",
#       "type": "f"
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": 19,
#       "rops": 2,
#       "wbytes": 0,
#       "wops": 0
#     },
#     "net": {
#       "dip": "",
#       "dport": null,
#       "proto": "",
#       "sip": "",
#       "sport": null
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "O   R   C  ",
#     "opflags_bitmap": 1408,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "/usr/bin/healthcheck.sh",
#       "createts": 1555013928591289749,
#       "entry": "",
#       "exe": "/usr/bin/healthcheck.sh",
#       "gid": 0,
#       "group": "root",
#       "pid": 17064,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "proc": {
#       "args": "-nplt",
#       "createts": 1555013928596730857,
#       "entry": "",
#       "exe": "/bin/netstat",
#       "gid": 0,
#       "group": "root",
#       "pid": 17065,
#       "tid": 17065,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "res": "/proc/1/cmdline",
#     "ret": null,
#     "schema": 1000,
#     "state": "MODIFIED",
#     "ts": "2019-04-11T20:18:48.597453",
#     "ts_uts": 1555013928597453390,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "2019-04-11T20:18:48.597549",
#     "endts_uts": 1555013928597549119,
#     "file": {
#       "fd": 4,
#       "newpath": "",
#       "openflags": 5121,
#       "path": "/proc/1/fd",
#       "type": "d"
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": 0,
#       "rops": 0,
#       "wbytes": 0,
#       "wops": 0
#     },
#     "net": {
#       "dip": "",
#       "dport": null,
#       "proto": "",
#       "sip": "",
#       "sport": null
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "O       C  ",
#     "opflags_bitmap": 1152,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "/usr/bin/healthcheck.sh",
#       "createts": 1555013928591289749,
#       "entry": "",
#       "exe": "/usr/bin/healthcheck.sh",
#       "gid": 0,
#       "group": "root",
#       "pid": 17064,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "proc": {
#       "args": "-nplt",
#       "createts": 1555013928596730857,
#       "entry": "",
#       "exe": "/bin/netstat",
#       "gid": 0,
#       "group": "root",
#       "pid": 17065,
#       "tid": 17065,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "res": "/proc/1/fd",
#     "ret": null,
#     "schema": 1000,
#     "state": "MODIFIED",
#     "ts": "2019-04-11T20:18:48.597475",
#     "ts_uts": 1555013928597474989,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "2019-04-11T20:18:48.597566",
#     "endts_uts": 1555013928597565759,
#     "file": {
#       "fd": 4,
#       "newpath": "",
#       "openflags": 1,
#       "path": "/proc/437/cmdline",
#       "type": "f"
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": 35,
#       "rops": 2,
#       "wbytes": 0,
#       "wops": 0
#     },
#     "net": {
#       "dip": "",
#       "dport": null,
#       "proto": "",
#       "sip": "",
#       "sport": null
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "O   R   C  ",
#     "opflags_bitmap": 1408,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "/usr/bin/healthcheck.sh",
#       "createts": 1555013928591289749,
#       "entry": "",
#       "exe": "/usr/bin/healthcheck.sh",
#       "gid": 0,
#       "group": "root",
#       "pid": 17064,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "proc": {
#       "args": "-nplt",
#       "createts": 1555013928596730857,
#       "entry": "",
#       "exe": "/bin/netstat",
#       "gid": 0,
#       "group": "root",
#       "pid": 17065,
#       "tid": 17065,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "res": "/proc/437/cmdline",
#     "ret": null,
#     "schema": 1000,
#     "state": "MODIFIED",
#     "ts": "2019-04-11T20:18:48.597559",
#     "ts_uts": 1555013928597559351,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "2019-04-11T20:18:48.597605",
#     "endts_uts": 1555013928597605365,
#     "file": {
#       "fd": 4,
#       "newpath": "",
#       "openflags": 5121,
#       "path": "/proc/437/fd",
#       "type": "d"
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": 0,
#       "rops": 0,
#       "wbytes": 0,
#       "wops": 0
#     },
#     "net": {
#       "dip": "",
#       "dport": null,
#       "proto": "",
#       "sip": "",
#       "sport": null
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "O       C  ",
#     "opflags_bitmap": 1152,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "/usr/bin/healthcheck.sh",
#       "createts": 1555013928591289749,
#       "entry": "",
#       "exe": "/usr/bin/healthcheck.sh",
#       "gid": 0,
#       "group": "root",
#       "pid": 17064,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "proc": {
#       "args": "-nplt",
#       "createts": 1555013928596730857,
#       "entry": "",
#       "exe": "/bin/netstat",
#       "gid": 0,
#       "group": "root",
#       "pid": 17065,
#       "tid": 17065,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "res": "/proc/437/fd",
#     "ret": null,
#     "schema": 1000,
#     "state": "MODIFIED",
#     "ts": "2019-04-11T20:18:48.597574",
#     "ts_uts": 1555013928597573734,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "2019-04-11T20:18:48.597620",
#     "endts_uts": 1555013928597619363,
#     "file": {
#       "fd": 4,
#       "newpath": "",
#       "openflags": 1,
#       "path": "/proc/441/cmdline",
#       "type": "f"
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": 32,
#       "rops": 2,
#       "wbytes": 0,
#       "wops": 0
#     },
#     "net": {
#       "dip": "",
#       "dport": null,
#       "proto": "",
#       "sip": "",
#       "sport": null
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "O   R   C  ",
#     "opflags_bitmap": 1408,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "/usr/bin/healthcheck.sh",
#       "createts": 1555013928591289749,
#       "entry": "",
#       "exe": "/usr/bin/healthcheck.sh",
#       "gid": 0,
#       "group": "root",
#       "pid": 17064,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "proc": {
#       "args": "-nplt",
#       "createts": 1555013928596730857,
#       "entry": "",
#       "exe": "/bin/netstat",
#       "gid": 0,
#       "group": "root",
#       "pid": 17065,
#       "tid": 17065,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "res": "/proc/441/cmdline",
#     "ret": null,
#     "schema": 1000,
#     "state": "MODIFIED",
#     "ts": "2019-04-11T20:18:48.597614",
#     "ts_uts": 1555013928597613855,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "2019-04-11T20:18:48.597674",
#     "endts_uts": 1555013928597673816,
#     "file": {
#       "fd": 4,
#       "newpath": "",
#       "openflags": 5121,
#       "path": "/proc/441/fd",
#       "type": "d"
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": 0,
#       "rops": 0,
#       "wbytes": 0,
#       "wops": 0
#     },
#     "net": {
#       "dip": "",
#       "dport": null,
#       "proto": "",
#       "sip": "",
#       "sport": null
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "O       C  ",
#     "opflags_bitmap": 1152,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "/usr/bin/healthcheck.sh",
#       "createts": 1555013928591289749,
#       "entry": "",
#       "exe": "/usr/bin/healthcheck.sh",
#       "gid": 0,
#       "group": "root",
#       "pid": 17064,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "proc": {
#       "args": "-nplt",
#       "createts": 1555013928596730857,
#       "entry": "",
#       "exe": "/bin/netstat",
#       "gid": 0,
#       "group": "root",
#       "pid": 17065,
#       "tid": 17065,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "res": "/proc/441/fd",
#     "ret": null,
#     "schema": 1000,
#     "state": "MODIFIED",
#     "ts": "2019-04-11T20:18:48.597627",
#     "ts_uts": 1555013928597627388,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "2019-04-11T20:18:48.597687",
#     "endts_uts": 1555013928597687442,
#     "file": {
#       "fd": 4,
#       "newpath": "",
#       "openflags": 1,
#       "path": "/proc/442/cmdline",
#       "type": "f"
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": 32,
#       "rops": 2,
#       "wbytes": 0,
#       "wops": 0
#     },
#     "net": {
#       "dip": "",
#       "dport": null,
#       "proto": "",
#       "sip": "",
#       "sport": null
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "O   R   C  ",
#     "opflags_bitmap": 1408,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "/usr/bin/healthcheck.sh",
#       "createts": 1555013928591289749,
#       "entry": "",
#       "exe": "/usr/bin/healthcheck.sh",
#       "gid": 0,
#       "group": "root",
#       "pid": 17064,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "proc": {
#       "args": "-nplt",
#       "createts": 1555013928596730857,
#       "entry": "",
#       "exe": "/bin/netstat",
#       "gid": 0,
#       "group": "root",
#       "pid": 17065,
#       "tid": 17065,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "res": "/proc/442/cmdline",
#     "ret": null,
#     "schema": 1000,
#     "state": "MODIFIED",
#     "ts": "2019-04-11T20:18:48.597682",
#     "ts_uts": 1555013928597681545,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "2019-04-11T20:18:48.597725",
#     "endts_uts": 1555013928597724940,
#     "file": {
#       "fd": 4,
#       "newpath": "",
#       "openflags": 5121,
#       "path": "/proc/442/fd",
#       "type": "d"
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": 0,
#       "rops": 0,
#       "wbytes": 0,
#       "wops": 0
#     },
#     "net": {
#       "dip": "",
#       "dport": null,
#       "proto": "",
#       "sip": "",
#       "sport": null
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "O       C  ",
#     "opflags_bitmap": 1152,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "/usr/bin/healthcheck.sh",
#       "createts": 1555013928591289749,
#       "entry": "",
#       "exe": "/usr/bin/healthcheck.sh",
#       "gid": 0,
#       "group": "root",
#       "pid": 17064,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "proc": {
#       "args": "-nplt",
#       "createts": 1555013928596730857,
#       "entry": "",
#       "exe": "/bin/netstat",
#       "gid": 0,
#       "group": "root",
#       "pid": 17065,
#       "tid": 17065,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "res": "/proc/442/fd",
#     "ret": null,
#     "schema": 1000,
#     "state": "MODIFIED",
#     "ts": "2019-04-11T20:18:48.597695",
#     "ts_uts": 1555013928597694986,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "2019-04-11T20:18:48.597738",
#     "endts_uts": 1555013928597737753,
#     "file": {
#       "fd": 4,
#       "newpath": "",
#       "openflags": 1,
#       "path": "/proc/443/cmdline",
#       "type": "f"
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": 14,
#       "rops": 2,
#       "wbytes": 0,
#       "wops": 0
#     },
#     "net": {
#       "dip": "",
#       "dport": null,
#       "proto": "",
#       "sip": "",
#       "sport": null
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "O   R   C  ",
#     "opflags_bitmap": 1408,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "/usr/bin/healthcheck.sh",
#       "createts": 1555013928591289749,
#       "entry": "",
#       "exe": "/usr/bin/healthcheck.sh",
#       "gid": 0,
#       "group": "root",
#       "pid": 17064,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "proc": {
#       "args": "-nplt",
#       "createts": 1555013928596730857,
#       "entry": "",
#       "exe": "/bin/netstat",
#       "gid": 0,
#       "group": "root",
#       "pid": 17065,
#       "tid": 17065,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "res": "/proc/443/cmdline",
#     "ret": null,
#     "schema": 1000,
#     "state": "MODIFIED",
#     "ts": "2019-04-11T20:18:48.597733",
#     "ts_uts": 1555013928597732752,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "2019-04-11T20:18:48.597788",
#     "endts_uts": 1555013928597788110,
#     "file": {
#       "fd": 4,
#       "newpath": "",
#       "openflags": 5121,
#       "path": "/proc/443/fd",
#       "type": "d"
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": 0,
#       "rops": 0,
#       "wbytes": 0,
#       "wops": 0
#     },
#     "net": {
#       "dip": "",
#       "dport": null,
#       "proto": "",
#       "sip": "",
#       "sport": null
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "O       C  ",
#     "opflags_bitmap": 1152,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "/usr/bin/healthcheck.sh",
#       "createts": 1555013928591289749,
#       "entry": "",
#       "exe": "/usr/bin/healthcheck.sh",
#       "gid": 0,
#       "group": "root",
#       "pid": 17064,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "proc": {
#       "args": "-nplt",
#       "createts": 1555013928596730857,
#       "entry": "",
#       "exe": "/bin/netstat",
#       "gid": 0,
#       "group": "root",
#       "pid": 17065,
#       "tid": 17065,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "res": "/proc/443/fd",
#     "ret": null,
#     "schema": 1000,
#     "state": "MODIFIED",
#     "ts": "2019-04-11T20:18:48.597745",
#     "ts_uts": 1555013928597745452,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "2019-04-11T20:18:48.597805",
#     "endts_uts": 1555013928597804894,
#     "file": {
#       "fd": 4,
#       "newpath": "",
#       "openflags": 1,
#       "path": "/proc/444/cmdline",
#       "type": "f"
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": 60,
#       "rops": 2,
#       "wbytes": 0,
#       "wops": 0
#     },
#     "net": {
#       "dip": "",
#       "dport": null,
#       "proto": "",
#       "sip": "",
#       "sport": null
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "O   R   C  ",
#     "opflags_bitmap": 1408,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "/usr/bin/healthcheck.sh",
#       "createts": 1555013928591289749,
#       "entry": "",
#       "exe": "/usr/bin/healthcheck.sh",
#       "gid": 0,
#       "group": "root",
#       "pid": 17064,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "proc": {
#       "args": "-nplt",
#       "createts": 1555013928596730857,
#       "entry": "",
#       "exe": "/bin/netstat",
#       "gid": 0,
#       "group": "root",
#       "pid": 17065,
#       "tid": 17065,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "res": "/proc/444/cmdline",
#     "ret": null,
#     "schema": 1000,
#     "state": "MODIFIED",
#     "ts": "2019-04-11T20:18:48.597800",
#     "ts_uts": 1555013928597799361,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "2019-04-11T20:18:48.597850",
#     "endts_uts": 1555013928597850273,
#     "file": {
#       "fd": 4,
#       "newpath": "",
#       "openflags": 5121,
#       "path": "/proc/444/fd",
#       "type": "d"
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": 0,
#       "rops": 0,
#       "wbytes": 0,
#       "wops": 0
#     },
#     "net": {
#       "dip": "",
#       "dport": null,
#       "proto": "",
#       "sip": "",
#       "sport": null
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "O       C  ",
#     "opflags_bitmap": 1152,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "/usr/bin/healthcheck.sh",
#       "createts": 1555013928591289749,
#       "entry": "",
#       "exe": "/usr/bin/healthcheck.sh",
#       "gid": 0,
#       "group": "root",
#       "pid": 17064,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "proc": {
#       "args": "-nplt",
#       "createts": 1555013928596730857,
#       "entry": "",
#       "exe": "/bin/netstat",
#       "gid": 0,
#       "group": "root",
#       "pid": 17065,
#       "tid": 17065,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "res": "/proc/444/fd",
#     "ret": null,
#     "schema": 1000,
#     "state": "MODIFIED",
#     "ts": "2019-04-11T20:18:48.597814",
#     "ts_uts": 1555013928597814044,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "2019-04-11T20:18:48.597853",
#     "endts_uts": 1555013928597852918,
#     "file": {
#       "fd": 3,
#       "newpath": "",
#       "openflags": 5121,
#       "path": "/proc",
#       "type": "d"
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": 0,
#       "rops": 0,
#       "wbytes": 0,
#       "wops": 0
#     },
#     "net": {
#       "dip": "",
#       "dport": null,
#       "proto": "",
#       "sip": "",
#       "sport": null
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "O       C  ",
#     "opflags_bitmap": 1152,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "/usr/bin/healthcheck.sh",
#       "createts": 1555013928591289749,
#       "entry": "",
#       "exe": "/usr/bin/healthcheck.sh",
#       "gid": 0,
#       "group": "root",
#       "pid": 17064,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "proc": {
#       "args": "-nplt",
#       "createts": 1555013928596730857,
#       "entry": "",
#       "exe": "/bin/netstat",
#       "gid": 0,
#       "group": "root",
#       "pid": 17065,
#       "tid": 17065,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "res": "/proc",
#     "ret": null,
#     "schema": 1000,
# ...
#       "gid": 0,
#       "group": "root",
#       "pid": 13144,
#       "tid": 13144,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "res": "/data/.minio.sys/buckets/play/tcpclientserver/fs.json",
#     "ret": null,
#     "schema": 1000,
#     "state": "REUP",
#     "ts": "2019-04-11T20:18:50.207677",
#     "ts_uts": 1555013930207676814,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "2019-04-11T20:18:50.208770",
#     "endts_uts": 1555013930208769859,
#     "file": {
#       "fd": 6,
#       "newpath": "",
#       "openflags": "",
#       "path": "",
#       "type": ""
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": 1537,
#       "rops": 6,
#       "wbytes": 0,
#       "wops": 0
#     },
#     "net": {
#       "dip": "172.17.0.4",
#       "dport": 9000,
#       "proto": 6,
#       "sip": "172.17.0.5",
#       "sport": 52942
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": " A  R    T ",
#     "opflags_bitmap": 2336,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "-namespace moby -workdir /var/lib/docker/containerd/daemon/io.containerd.runtime.v1.linux/moby/8661fade8683f3269e07346e7ebace7eef622fc0a9c57677cf4a8318237ebfcc -address /var/run/docker/containerd/docker-containerd.sock -containerd-binary /usr/bin/docker-containerd -runtime-root /var/run/docker/runtime-runc",
#       "createts": 0,
#       "entry": "",
#       "exe": "/usr/bin/docker-containerd-shim",
#       "gid": 0,
#       "group": "root",
#       "pid": 13116,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "proc": {
#       "args": "server /data",
#       "createts": 0,
#       "entry": "",
#       "exe": "/usr/bin/minio",
#       "gid": 0,
#       "group": "root",
#       "pid": 13144,
#       "tid": 13185,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "res": "172.17.0.5:52942-172.17.0.4:9000",
#     "ret": null,
#     "schema": 1000,
#     "state": "REUP",
#     "ts": "2019-04-11T20:18:50.203071",
#     "ts_uts": 1555013930203070983,
#     "type": "NF",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "2019-04-11T20:18:50.208770",
#     "endts_uts": 1555013930208769859,
#     "file": {
#       "fd": 6,
#       "newpath": "",
#       "openflags": "",
#       "path": "",
#       "type": ""
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": 482,
#       "rops": 2,
#       "wbytes": 11727,
#       "wops": 3
#     },
#     "net": {
#       "dip": "172.17.0.4",
#       "dport": 9000,
#       "proto": 6,
#       "sip": "172.17.0.5",
#       "sport": 52942
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "   WR    T ",
#     "opflags_bitmap": 2816,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "-namespace moby -workdir /var/lib/docker/containerd/daemon/io.containerd.runtime.v1.linux/moby/8661fade8683f3269e07346e7ebace7eef622fc0a9c57677cf4a8318237ebfcc -address /var/run/docker/containerd/docker-containerd.sock -containerd-binary /usr/bin/docker-containerd -runtime-root /var/run/docker/runtime-runc",
#       "createts": 0,
#       "entry": "",
#       "exe": "/usr/bin/docker-containerd-shim",
#       "gid": 0,
#       "group": "root",
#       "pid": 13116,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "proc": {
#       "args": "server /data",
#       "createts": 0,
#       "entry": "",
#       "exe": "/usr/bin/minio",
#       "gid": 0,
#       "group": "root",
#       "pid": 13144,
#       "tid": 13179,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "res": "172.17.0.5:52942-172.17.0.4:9000",
#     "ret": null,
#     "schema": 1000,
#     "state": "REUP",
#     "ts": "2019-04-11T20:18:50.203867",
#     "ts_uts": 1555013930203867227,
#     "type": "NF",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "2019-04-11T20:18:50.208770",
#     "endts_uts": 1555013930208769859,
#     "file": {
#       "fd": 6,
#       "newpath": "",
#       "openflags": "",
#       "path": "",
#       "type": ""
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": 0,
#       "rops": 1,
#       "wbytes": 13967,
#       "wops": 4
#     },
#     "net": {
#       "dip": "172.17.0.4",
#       "dport": 9000,
#       "proto": 6,
#       "sip": "172.17.0.5",
#       "sport": 52942
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "   WR   C  ",
#     "opflags_bitmap": 1792,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "-namespace moby -workdir /var/lib/docker/containerd/daemon/io.containerd.runtime.v1.linux/moby/8661fade8683f3269e07346e7ebace7eef622fc0a9c57677cf4a8318237ebfcc -address /var/run/docker/containerd/docker-containerd.sock -containerd-binary /usr/bin/docker-containerd -runtime-root /var/run/docker/runtime-runc",
#       "createts": 0,
#       "entry": "",
#       "exe": "/usr/bin/docker-containerd-shim",
#       "gid": 0,
#       "group": "root",
#       "pid": 13116,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "proc": {
#       "args": "server /data",
#       "createts": 0,
#       "entry": "",
#       "exe": "/usr/bin/minio",
#       "gid": 0,
#       "group": "root",
#       "pid": 13144,
#       "tid": 13144,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "res": "172.17.0.5:52942-172.17.0.4:9000",
#     "ret": null,
#     "schema": 1000,
#     "state": "REUP",
#     "ts": "2019-04-11T20:18:50.205752",
#     "ts_uts": 1555013930205751818,
#     "type": "NF",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "2019-04-11T20:18:50.209216",
#     "endts_uts": 1555013930209216373,
#     "file": {
#       "fd": 7,
#       "newpath": "",
#       "openflags": 4241,
#       "path": "/data/.minio.sys/buckets/play/tcpclientserver/fs.json",
#       "type": "f"
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": 168,
#       "rops": 1,
#       "wbytes": 0,
#       "wops": 0
#     },
#     "net": {
#       "dip": "",
#       "dport": null,
#       "proto": "",
#       "sip": "",
#       "sport": null
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "O   R   C  ",
#     "opflags_bitmap": 1408,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "-namespace moby -workdir /var/lib/docker/containerd/daemon/io.containerd.runtime.v1.linux/moby/8661fade8683f3269e07346e7ebace7eef622fc0a9c57677cf4a8318237ebfcc -address /var/run/docker/containerd/docker-containerd.sock -containerd-binary /usr/bin/docker-containerd -runtime-root /var/run/docker/runtime-runc",
#       "createts": 0,
#       "entry": "",
#       "exe": "/usr/bin/docker-containerd-shim",
#       "gid": 0,
#       "group": "root",
#       "pid": 13116,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "proc": {
#       "args": "server /data",
#       "createts": 0,
#       "entry": "",
#       "exe": "/usr/bin/minio",
#       "gid": 0,
#       "group": "root",
#       "pid": 13144,
#       "tid": 13185,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "res": "/data/.minio.sys/buckets/play/tcpclientserver/fs.json",
#     "ret": null,
#     "schema": 1000,
#     "state": "REUP",
#     "ts": "2019-04-11T20:18:50.209183",
#     "ts_uts": 1555013930209183475,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "2019-04-11T20:18:50.212138",
#     "endts_uts": 1555013930212138203,
#     "file": {
#       "fd": 8,
#       "newpath": "",
#       "openflags": 4097,
#       "path": "/data/play/tcpclientserver",
#       "type": "f"
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": 12571,
#       "rops": 1,
#       "wbytes": 0,
#       "wops": 0
#     },
#     "net": {
#       "dip": "",
#       "dport": null,
#       "proto": "",
#       "sip": "",
#       "sport": null
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "O   R   C  ",
#     "opflags_bitmap": 1408,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "-namespace moby -workdir /var/lib/docker/containerd/daemon/io.containerd.runtime.v1.linux/moby/8661fade8683f3269e07346e7ebace7eef622fc0a9c57677cf4a8318237ebfcc -address /var/run/docker/containerd/docker-containerd.sock -containerd-binary /usr/bin/docker-containerd -runtime-root /var/run/docker/runtime-runc",
#       "createts": 0,
#       "entry": "",
#       "exe": "/usr/bin/docker-containerd-shim",
#       "gid": 0,
#       "group": "root",
#       "pid": 13116,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "proc": {
#       "args": "server /data",
#       "createts": 0,
#       "entry": "",
#       "exe": "/usr/bin/minio",
#       "gid": 0,
#       "group": "root",
#       "pid": 13144,
#       "tid": 13185,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "res": "/data/play/tcpclientserver",
#     "ret": null,
#     "schema": 1000,
#     "state": "REUP",
#     "ts": "2019-04-11T20:18:50.209329",
#     "ts_uts": 1555013930209329015,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "2019-04-11T20:18:50.212146",
#     "endts_uts": 1555013930212145589,
#     "file": {
#       "fd": 7,
#       "newpath": "",
#       "openflags": 4241,
#       "path": "/data/.minio.sys/buckets/play/tcpclientserver/fs.json",
#       "type": "f"
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": 168,
#       "rops": 1,
#       "wbytes": 0,
#       "wops": 0
#     },
#     "net": {
#       "dip": "",
#       "dport": null,
#       "proto": "",
#       "sip": "",
#       "sport": null
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "O   R   C  ",
#     "opflags_bitmap": 1408,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "-namespace moby -workdir /var/lib/docker/containerd/daemon/io.containerd.runtime.v1.linux/moby/8661fade8683f3269e07346e7ebace7eef622fc0a9c57677cf4a8318237ebfcc -address /var/run/docker/containerd/docker-containerd.sock -containerd-binary /usr/bin/docker-containerd -runtime-root /var/run/docker/runtime-runc",
#       "createts": 0,
#       "entry": "",
#       "exe": "/usr/bin/docker-containerd-shim",
#       "gid": 0,
#       "group": "root",
#       "pid": 13116,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "proc": {
#       "args": "server /data",
#       "createts": 0,
#       "entry": "",
#       "exe": "/usr/bin/minio",
#       "gid": 0,
#       "group": "root",
#       "pid": 13144,
#       "tid": 13185,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "res": "/data/.minio.sys/buckets/play/tcpclientserver/fs.json",
#     "ret": null,
#     "schema": 1000,
#     "state": "REUP",
#     "ts": "2019-04-11T20:18:50.209297",
#     "ts_uts": 1555013930209297099,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "2019-04-11T20:18:50.212518",
#     "endts_uts": 1555013930212518268,
#     "file": {
#       "fd": 6,
#       "newpath": "",
#       "openflags": "",
#       "path": "",
#       "type": ""
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": 537,
#       "rops": 2,
#       "wbytes": 0,
#       "wops": 0
#     },
#     "net": {
#       "dip": "172.17.0.4",
#       "dport": 9000,
#       "proto": 6,
#       "sip": "172.17.0.5",
#       "sport": 52944
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": " A  R    T ",
#     "opflags_bitmap": 2336,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "-namespace moby -workdir /var/lib/docker/containerd/daemon/io.containerd.runtime.v1.linux/moby/8661fade8683f3269e07346e7ebace7eef622fc0a9c57677cf4a8318237ebfcc -address /var/run/docker/containerd/docker-containerd.sock -containerd-binary /usr/bin/docker-containerd -runtime-root /var/run/docker/runtime-runc",
#       "createts": 0,
#       "entry": "",
#       "exe": "/usr/bin/docker-containerd-shim",
#       "gid": 0,
#       "group": "root",
#       "pid": 13116,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "proc": {
#       "args": "server /data",
#       "createts": 0,
#       "entry": "",
#       "exe": "/usr/bin/minio",
#       "gid": 0,
#       "group": "root",
#       "pid": 13144,
#       "tid": 13179,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "res": "172.17.0.5:52944-172.17.0.4:9000",
#     "ret": null,
#     "schema": 1000,
#     "state": "REUP",
#     "ts": "2019-04-11T20:18:50.208804",
#     "ts_uts": 1555013930208803615,
#     "type": "NF",
#     "version": "3"
#   },
#   {
#     "container": {
#       "id": "8661fade8683",
#       "image": "minio/minio/latest",
#       "imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#       "name": "minio",
#       "privileged": false,
#       "type": "CT_DOCKER"
#     },
#     "endts": "2019-04-11T20:18:50.212518",
#     "endts_uts": 1555013930212518268,
#     "file": {
#       "fd": 6,
#       "newpath": "",
#       "openflags": "",
#       "path": "",
#       "type": ""
#     },
#     "filename": "",
#     "flow": {
#       "rbytes": 0,
#       "rops": 1,
#       "wbytes": 12992,
#       "wops": 2
#     },
#     "net": {
#       "dip": "172.17.0.4",
#       "dport": 9000,
#       "proto": 6,
#       "sip": "172.17.0.5",
#       "sport": 52944
#     },
#     "node": {
#       "id": "tests",
#       "ip": ""
#     },
#     "opflags": "   WR   C  ",
#     "opflags_bitmap": 1792,
#     "pf": {
#       "nerrors": null,
#       "nexits": null,
#       "nthreads": null
#     },
#     "pproc": {
#       "args": "-namespace moby -workdir /var/lib/docker/containerd/daemon/io.containerd.runtime.v1.linux/moby/8661fade8683f3269e07346e7ebace7eef622fc0a9c57677cf4a8318237ebfcc -address /var/run/docker/containerd/docker-containerd.sock -containerd-binary /usr/bin/docker-containerd -runtime-root /var/run/docker/runtime-runc",
#       "createts": 0,
#       "entry": "",
#       "exe": "/usr/bin/docker-containerd-shim",
#       "gid": 0,
#       "group": "root",
#       "pid": 13116,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "proc": {
#       "args": "server /data",
#       "createts": 0,
#       "entry": "",
#       "exe": "/usr/bin/minio",
#       "gid": 0,
#       "group": "root",
#       "pid": 13144,
#       "tid": 13185,
#       "tty": false,
#       "uid": 0,
#       "user": "root"
#     },
#     "res": "172.17.0.5:52944-172.17.0.4:9000",
#     "ret": null,
#     "schema": 1000,
#     "state": "REUP",
#     "ts": "2019-04-11T20:18:50.209523",
#     "ts_uts": 1555013930209523058,
#     "type": "NF",
#     "version": "3"
#   }
# ]

# %%
# We can also dump sysflow records in a "flat" representation
import json
reader = FlattenedSFReader(trace)
formatter = SFFormatter(reader)
formatter.toJsonFile(path='/tmp/json', flat=True)
with open('/tmp/json') as jsonfile:
    js =json.load(jsonfile)
print(json.dumps(js, indent=2, sort_keys=True))
# Out:
# [
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "",
#     "endts_uts": null,
#     "file.fd": "",
#     "file.newpath": "",
#     "file.openflags": "",
#     "file.path": "",
#     "file.type": "",
#     "filename": "",
#     "flow.rbytes": null,
#     "flow.rops": null,
#     "flow.wbytes": null,
#     "flow.wops": null,
#     "net.dip": "",
#     "net.dport": null,
#     "net.proto": "",
#     "net.sip": "",
#     "net.sport": null,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "CLONE",
#     "opflags_bitmap": 1,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "",
#     "pproc.createts": "",
#     "pproc.entry": "",
#     "pproc.exe": "",
#     "pproc.gid": null,
#     "pproc.group": "",
#     "pproc.pid": null,
#     "pproc.tty": "",
#     "pproc.uid": null,
#     "pproc.user": "",
#     "proc.args": "init",
#     "proc.createts": 0,
#     "proc.entry": "",
#     "proc.exe": "docker-runc",
#     "proc.gid": -1,
#     "proc.group": "",
#     "proc.pid": 17059,
#     "proc.tid": 17061,
#     "proc.tty": false,
#     "proc.uid": -1,
#     "proc.user": "",
#     "res": "",
#     "ret": 0,
#     "schema": 1000,
#     "state": "CREATED",
#     "ts": "2019-04-11T20:18:48.557415",
#     "ts_uts": 1555013928557415261,
#     "type": "PE",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "",
#     "endts_uts": null,
#     "file.fd": "",
#     "file.newpath": "",
#     "file.openflags": "",
#     "file.path": "",
#     "file.type": "",
#     "filename": "",
#     "flow.rbytes": null,
#     "flow.rops": null,
#     "flow.wbytes": null,
#     "flow.wops": null,
#     "net.dip": "",
#     "net.dport": null,
#     "net.proto": "",
#     "net.sip": "",
#     "net.sport": null,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "CLONE",
#     "opflags_bitmap": 1,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "",
#     "pproc.createts": "",
#     "pproc.entry": "",
#     "pproc.exe": "",
#     "pproc.gid": null,
#     "pproc.group": "",
#     "pproc.pid": null,
#     "pproc.tty": "",
#     "pproc.uid": null,
#     "pproc.user": "",
#     "proc.args": "init",
#     "proc.createts": 0,
#     "proc.entry": "",
#     "proc.exe": "docker-runc",
#     "proc.gid": -1,
#     "proc.group": "",
#     "proc.pid": 17059,
#     "proc.tid": 17060,
#     "proc.tty": false,
#     "proc.uid": -1,
#     "proc.user": "",
#     "res": "",
#     "ret": 0,
#     "schema": 1000,
#     "state": "CREATED",
#     "ts": "2019-04-11T20:18:48.558260",
#     "ts_uts": 1555013928558260218,
#     "type": "PE",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "",
#     "endts_uts": null,
#     "file.fd": "",
#     "file.newpath": "",
#     "file.openflags": "",
#     "file.path": "",
#     "file.type": "",
#     "filename": "",
#     "flow.rbytes": null,
#     "flow.rops": null,
#     "flow.wbytes": null,
#     "flow.wops": null,
#     "net.dip": "",
#     "net.dport": null,
#     "net.proto": "",
#     "net.sip": "",
#     "net.sport": null,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "CLONE",
#     "opflags_bitmap": 1,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "",
#     "pproc.createts": "",
#     "pproc.entry": "",
#     "pproc.exe": "",
#     "pproc.gid": null,
#     "pproc.group": "",
#     "pproc.pid": null,
#     "pproc.tty": "",
#     "pproc.uid": null,
#     "pproc.user": "",
#     "proc.args": "init",
#     "proc.createts": 0,
#     "proc.entry": "",
#     "proc.exe": "docker-runc",
#     "proc.gid": -1,
#     "proc.group": "",
#     "proc.pid": 17059,
#     "proc.tid": 17062,
#     "proc.tty": false,
#     "proc.uid": -1,
#     "proc.user": "",
#     "res": "",
#     "ret": 0,
#     "schema": 1000,
#     "state": "CREATED",
#     "ts": "2019-04-11T20:18:48.558287",
#     "ts_uts": 1555013928558287176,
#     "type": "PE",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "",
#     "endts_uts": null,
#     "file.fd": "",
#     "file.newpath": "",
#     "file.openflags": "",
#     "file.path": "",
#     "file.type": "",
#     "filename": "",
#     "flow.rbytes": null,
#     "flow.rops": null,
#     "flow.wbytes": null,
#     "flow.wops": null,
#     "net.dip": "",
#     "net.dport": null,
#     "net.proto": "",
#     "net.sip": "",
#     "net.sport": null,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "EXIT",
#     "opflags_bitmap": 4,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "",
#     "pproc.createts": "",
#     "pproc.entry": "",
#     "pproc.exe": "",
#     "pproc.gid": null,
#     "pproc.group": "",
#     "pproc.pid": null,
#     "pproc.tty": "",
#     "pproc.uid": null,
#     "pproc.user": "",
#     "proc.args": "init",
#     "proc.createts": 0,
#     "proc.entry": "",
#     "proc.exe": "docker-runc",
#     "proc.gid": -1,
#     "proc.group": "",
#     "proc.pid": 17059,
#     "proc.tid": 17060,
#     "proc.tty": false,
#     "proc.uid": -1,
#     "proc.user": "",
#     "res": "",
#     "ret": 0,
#     "schema": 1000,
#     "state": "CREATED",
#     "ts": "2019-04-11T20:18:48.586449",
#     "ts_uts": 1555013928586448628,
#     "type": "PE",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "",
#     "endts_uts": null,
#     "file.fd": "",
#     "file.newpath": "",
#     "file.openflags": "",
#     "file.path": "",
#     "file.type": "",
#     "filename": "",
#     "flow.rbytes": null,
#     "flow.rops": null,
#     "flow.wbytes": null,
#     "flow.wops": null,
#     "net.dip": "",
#     "net.dport": null,
#     "net.proto": "",
#     "net.sip": "",
#     "net.sport": null,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "EXIT",
#     "opflags_bitmap": 4,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "",
#     "pproc.createts": "",
#     "pproc.entry": "",
#     "pproc.exe": "",
#     "pproc.gid": null,
#     "pproc.group": "",
#     "pproc.pid": null,
#     "pproc.tty": "",
#     "pproc.uid": null,
#     "pproc.user": "",
#     "proc.args": "init",
#     "proc.createts": 0,
#     "proc.entry": "",
#     "proc.exe": "docker-runc",
#     "proc.gid": -1,
#     "proc.group": "",
#     "proc.pid": 17059,
#     "proc.tid": 17061,
#     "proc.tty": false,
#     "proc.uid": -1,
#     "proc.user": "",
#     "res": "",
#     "ret": 0,
#     "schema": 1000,
#     "state": "CREATED",
#     "ts": "2019-04-11T20:18:48.586463",
#     "ts_uts": 1555013928586462941,
#     "type": "PE",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "",
#     "endts_uts": null,
#     "file.fd": "",
#     "file.newpath": "",
#     "file.openflags": "",
#     "file.path": "",
#     "file.type": "",
#     "filename": "",
#     "flow.rbytes": null,
#     "flow.rops": null,
#     "flow.wbytes": null,
#     "flow.wops": null,
#     "net.dip": "",
#     "net.dport": null,
#     "net.proto": "",
#     "net.sip": "",
#     "net.sport": null,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "EXIT",
#     "opflags_bitmap": 4,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "",
#     "pproc.createts": "",
#     "pproc.entry": "",
#     "pproc.exe": "",
#     "pproc.gid": null,
#     "pproc.group": "",
#     "pproc.pid": null,
#     "pproc.tty": "",
#     "pproc.uid": null,
#     "pproc.user": "",
#     "proc.args": "init",
#     "proc.createts": 0,
#     "proc.entry": "",
#     "proc.exe": "docker-runc",
#     "proc.gid": -1,
#     "proc.group": "",
#     "proc.pid": 17059,
#     "proc.tid": 17062,
#     "proc.tty": false,
#     "proc.uid": -1,
#     "proc.user": "",
#     "res": "",
#     "ret": 0,
#     "schema": 1000,
#     "state": "CREATED",
#     "ts": "2019-04-11T20:18:48.586470",
#     "ts_uts": 1555013928586469785,
#     "type": "PE",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "",
#     "endts_uts": null,
#     "file.fd": "",
#     "file.newpath": "",
#     "file.openflags": "",
#     "file.path": "",
#     "file.type": "",
#     "filename": "",
#     "flow.rbytes": null,
#     "flow.rops": null,
#     "flow.wbytes": null,
#     "flow.wops": null,
#     "net.dip": "",
#     "net.dport": null,
#     "net.proto": "",
#     "net.sip": "",
#     "net.sport": null,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "EXEC",
#     "opflags_bitmap": 2,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "",
#     "pproc.createts": "",
#     "pproc.entry": "",
#     "pproc.exe": "",
#     "pproc.gid": null,
#     "pproc.group": "",
#     "pproc.pid": null,
#     "pproc.tty": "",
#     "pproc.uid": null,
#     "pproc.user": "",
#     "proc.args": "-c /usr/bin/healthcheck.sh",
#     "proc.createts": 0,
#     "proc.entry": "",
#     "proc.exe": "/bin/dash",
#     "proc.gid": -1,
#     "proc.group": "",
#     "proc.pid": 17059,
#     "proc.tid": 17059,
#     "proc.tty": false,
#     "proc.uid": -1,
#     "proc.user": "",
#     "res": "",
#     "ret": 0,
#     "schema": 1000,
#     "state": "MODIFIED",
#     "ts": "2019-04-11T20:18:48.586900",
#     "ts_uts": 1555013928586900387,
#     "type": "PE",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "",
#     "endts_uts": null,
#     "file.fd": "",
#     "file.newpath": "",
#     "file.openflags": "",
#     "file.path": "",
#     "file.type": "",
#     "filename": "",
#     "flow.rbytes": null,
#     "flow.rops": null,
#     "flow.wbytes": null,
#     "flow.wops": null,
#     "net.dip": "",
#     "net.dport": null,
#     "net.proto": "",
#     "net.sip": "",
#     "net.sport": null,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "EXEC",
#     "opflags_bitmap": 2,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "-c /usr/bin/healthcheck.sh",
#     "pproc.createts": 0,
#     "pproc.entry": "",
#     "pproc.exe": "/bin/dash",
#     "pproc.gid": -1,
#     "pproc.group": "",
#     "pproc.pid": 17059,
#     "pproc.tty": false,
#     "pproc.uid": -1,
#     "pproc.user": "",
#     "proc.args": "/usr/bin/healthcheck.sh",
#     "proc.createts": 1555013928590063189,
#     "proc.entry": "",
#     "proc.exe": "/usr/bin/healthcheck.sh",
#     "proc.gid": 0,
#     "proc.group": "root",
#     "proc.pid": 17063,
#     "proc.tid": 17063,
#     "proc.tty": false,
#     "proc.uid": 0,
#     "proc.user": "root",
#     "res": "",
#     "ret": 0,
#     "schema": 1000,
#     "state": "CREATED",
#     "ts": "2019-04-11T20:18:48.590213",
#     "ts_uts": 1555013928590212928,
#     "type": "PE",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "2019-04-11T20:18:48.590440",
#     "endts_uts": 1555013928590439695,
#     "file.fd": 3,
#     "file.newpath": "",
#     "file.openflags": 1,
#     "file.path": "/usr/bin/healthcheck.sh",
#     "file.type": "f",
#     "filename": "",
#     "flow.rbytes": 0,
#     "flow.rops": 0,
#     "flow.wbytes": 0,
#     "flow.wops": 0,
#     "net.dip": "",
#     "net.dport": null,
#     "net.proto": "",
#     "net.sip": "",
#     "net.sport": null,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "O       C  ",
#     "opflags_bitmap": 1152,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "-c /usr/bin/healthcheck.sh",
#     "pproc.createts": 0,
#     "pproc.entry": "",
#     "pproc.exe": "/bin/dash",
#     "pproc.gid": -1,
#     "pproc.group": "",
#     "pproc.pid": 17059,
#     "pproc.tty": false,
#     "pproc.uid": -1,
#     "pproc.user": "",
#     "proc.args": "/usr/bin/healthcheck.sh",
#     "proc.createts": 1555013928590063189,
#     "proc.entry": "",
#     "proc.exe": "/usr/bin/healthcheck.sh",
#     "proc.gid": 0,
#     "proc.group": "root",
#     "proc.pid": 17063,
#     "proc.tid": 17063,
#     "proc.tty": false,
#     "proc.uid": 0,
#     "proc.user": "root",
#     "res": "/usr/bin/healthcheck.sh",
#     "ret": null,
#     "schema": 1000,
#     "state": "CREATED",
#     "ts": "2019-04-11T20:18:48.590435",
#     "ts_uts": 1555013928590435074,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "2019-04-11T20:18:48.591278",
#     "endts_uts": 1555013928591278246,
#     "file.fd": 4,
#     "file.newpath": "",
#     "file.openflags": 0,
#     "file.path": "",
#     "file.type": "p",
#     "filename": "",
#     "flow.rbytes": 0,
#     "flow.rops": 0,
#     "flow.wbytes": 0,
#     "flow.wops": 0,
#     "net.dip": "",
#     "net.dport": null,
#     "net.proto": "",
#     "net.sip": "",
#     "net.sport": null,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "        C  ",
#     "opflags_bitmap": 1024,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "-c /usr/bin/healthcheck.sh",
#     "pproc.createts": 0,
#     "pproc.entry": "",
#     "pproc.exe": "/bin/dash",
#     "pproc.gid": -1,
#     "pproc.group": "",
#     "pproc.pid": 17059,
#     "pproc.tty": false,
#     "pproc.uid": -1,
#     "pproc.user": "",
#     "proc.args": "/usr/bin/healthcheck.sh",
#     "proc.createts": 1555013928590063189,
#     "proc.entry": "",
#     "proc.exe": "/usr/bin/healthcheck.sh",
#     "proc.gid": 0,
#     "proc.group": "root",
#     "proc.pid": 17063,
#     "proc.tid": 17063,
#     "proc.tty": false,
#     "proc.uid": 0,
#     "proc.user": "root",
#     "res": "",
#     "ret": null,
#     "schema": 1000,
#     "state": "CREATED",
#     "ts": "2019-04-11T20:18:48.591278",
#     "ts_uts": 1555013928591278246,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "2019-04-11T20:18:48.591327",
#     "endts_uts": 1555013928591327433,
#     "file.fd": 10,
#     "file.newpath": "",
#     "file.openflags": 0,
#     "file.path": "/usr/bin/healthcheck.sh",
#     "file.type": "f",
#     "filename": "",
#     "flow.rbytes": 0,
#     "flow.rops": 0,
#     "flow.wbytes": 0,
#     "flow.wops": 0,
#     "net.dip": "",
#     "net.dport": null,
#     "net.proto": "",
#     "net.sip": "",
#     "net.sport": null,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "        C  ",
#     "opflags_bitmap": 1024,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "/usr/bin/healthcheck.sh",
#     "pproc.createts": 1555013928590063189,
#     "pproc.entry": "",
#     "pproc.exe": "/usr/bin/healthcheck.sh",
#     "pproc.gid": 0,
#     "pproc.group": "root",
#     "pproc.pid": 17063,
#     "pproc.tty": false,
#     "pproc.uid": 0,
#     "pproc.user": "root",
#     "proc.args": "/usr/bin/healthcheck.sh",
#     "proc.createts": 1555013928591289749,
#     "proc.entry": "",
#     "proc.exe": "/usr/bin/healthcheck.sh",
#     "proc.gid": 0,
#     "proc.group": "root",
#     "proc.pid": 17064,
#     "proc.tid": 17064,
#     "proc.tty": false,
#     "proc.uid": 0,
#     "proc.user": "root",
#     "res": "/usr/bin/healthcheck.sh",
#     "ret": null,
#     "schema": 1000,
#     "state": "REUP",
#     "ts": "2019-04-11T20:18:48.591327",
#     "ts_uts": 1555013928591327433,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "2019-04-11T20:18:48.591332",
#     "endts_uts": 1555013928591331723,
#     "file.fd": 3,
#     "file.newpath": "",
#     "file.openflags": 0,
#     "file.path": "",
#     "file.type": "p",
#     "filename": "",
#     "flow.rbytes": 0,
#     "flow.rops": 0,
#     "flow.wbytes": 0,
#     "flow.wops": 0,
#     "net.dip": "",
#     "net.dport": null,
#     "net.proto": "",
#     "net.sip": "",
#     "net.sport": null,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "        C  ",
#     "opflags_bitmap": 1024,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "/usr/bin/healthcheck.sh",
#     "pproc.createts": 1555013928590063189,
#     "pproc.entry": "",
#     "pproc.exe": "/usr/bin/healthcheck.sh",
#     "pproc.gid": 0,
#     "pproc.group": "root",
#     "pproc.pid": 17063,
#     "pproc.tty": false,
#     "pproc.uid": 0,
#     "pproc.user": "root",
#     "proc.args": "/usr/bin/healthcheck.sh",
#     "proc.createts": 1555013928591289749,
#     "proc.entry": "",
#     "proc.exe": "/usr/bin/healthcheck.sh",
#     "proc.gid": 0,
#     "proc.group": "root",
#     "proc.pid": 17064,
#     "proc.tid": 17064,
#     "proc.tty": false,
#     "proc.uid": 0,
#     "proc.user": "root",
#     "res": "",
#     "ret": null,
#     "schema": 1000,
#     "state": "REUP",
#     "ts": "2019-04-11T20:18:48.591332",
#     "ts_uts": 1555013928591331723,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "2019-04-11T20:18:48.591439",
#     "endts_uts": 1555013928591438926,
#     "file.fd": 4,
#     "file.newpath": "",
#     "file.openflags": 0,
#     "file.path": "",
#     "file.type": "p",
#     "filename": "",
#     "flow.rbytes": 0,
#     "flow.rops": 0,
#     "flow.wbytes": 0,
#     "flow.wops": 0,
#     "net.dip": "",
#     "net.dport": null,
#     "net.proto": "",
#     "net.sip": "",
#     "net.sport": null,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "        C  ",
#     "opflags_bitmap": 1024,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "/usr/bin/healthcheck.sh",
#     "pproc.createts": 1555013928590063189,
#     "pproc.entry": "",
#     "pproc.exe": "/usr/bin/healthcheck.sh",
#     "pproc.gid": 0,
#     "pproc.group": "root",
#     "pproc.pid": 17063,
#     "pproc.tty": false,
#     "pproc.uid": 0,
#     "pproc.user": "root",
#     "proc.args": "/usr/bin/healthcheck.sh",
#     "proc.createts": 1555013928591289749,
#     "proc.entry": "",
#     "proc.exe": "/usr/bin/healthcheck.sh",
#     "proc.gid": 0,
#     "proc.group": "root",
#     "proc.pid": 17064,
#     "proc.tid": 17064,
#     "proc.tty": false,
#     "proc.uid": 0,
#     "proc.user": "root",
#     "res": "",
#     "ret": null,
#     "schema": 1000,
#     "state": "REUP",
#     "ts": "2019-04-11T20:18:48.591439",
#     "ts_uts": 1555013928591438926,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "2019-04-11T20:18:48.591520",
#     "endts_uts": 1555013928591520201,
#     "file.fd": 3,
#     "file.newpath": "",
#     "file.openflags": 0,
#     "file.path": "",
#     "file.type": "p",
#     "filename": "",
#     "flow.rbytes": 0,
#     "flow.rops": 0,
#     "flow.wbytes": 0,
#     "flow.wops": 0,
#     "net.dip": "",
#     "net.dport": null,
#     "net.proto": "",
#     "net.sip": "",
#     "net.sport": null,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "        C  ",
#     "opflags_bitmap": 1024,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "/usr/bin/healthcheck.sh",
#     "pproc.createts": 1555013928590063189,
#     "pproc.entry": "",
#     "pproc.exe": "/usr/bin/healthcheck.sh",
#     "pproc.gid": 0,
#     "pproc.group": "root",
#     "pproc.pid": 17063,
#     "pproc.tty": false,
#     "pproc.uid": 0,
#     "pproc.user": "root",
#     "proc.args": "/usr/bin/healthcheck.sh",
#     "proc.createts": 1555013928591289749,
#     "proc.entry": "",
#     "proc.exe": "/usr/bin/healthcheck.sh",
#     "proc.gid": 0,
#     "proc.group": "root",
#     "proc.pid": 17064,
#     "proc.tid": 17064,
#     "proc.tty": false,
#     "proc.uid": 0,
#     "proc.user": "root",
#     "res": "",
#     "ret": null,
#     "schema": 1000,
#     "state": "REUP",
#     "ts": "2019-04-11T20:18:48.591520",
#     "ts_uts": 1555013928591520201,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "",
#     "endts_uts": null,
#     "file.fd": "",
#     "file.newpath": "",
#     "file.openflags": "",
#     "file.path": "",
#     "file.type": "",
#     "filename": "",
#     "flow.rbytes": null,
#     "flow.rops": null,
#     "flow.wbytes": null,
#     "flow.wops": null,
#     "net.dip": "",
#     "net.dport": null,
#     "net.proto": "",
#     "net.sip": "",
#     "net.sport": null,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "EXEC",
#     "opflags_bitmap": 2,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "/usr/bin/healthcheck.sh",
#     "pproc.createts": 1555013928591289749,
#     "pproc.entry": "",
#     "pproc.exe": "/usr/bin/healthcheck.sh",
#     "pproc.gid": 0,
#     "pproc.group": "root",
#     "pproc.pid": 17064,
#     "pproc.tty": false,
#     "pproc.uid": 0,
#     "pproc.user": "root",
#     "proc.args": " /(.*\\/minio)/ { gsub(\":::\",\"127.0.0.1:\",$4); print $4}",
#     "proc.createts": 1555013928595224518,
#     "proc.entry": "",
#     "proc.exe": "/usr/bin/awk",
#     "proc.gid": 0,
#     "proc.group": "root",
#     "proc.pid": 17066,
#     "proc.tid": 17066,
#     "proc.tty": false,
#     "proc.uid": 0,
#     "proc.user": "root",
#     "res": "",
#     "ret": 0,
#     "schema": 1000,
#     "state": "CREATED",
#     "ts": "2019-04-11T20:18:48.596461",
#     "ts_uts": 1555013928596460518,
#     "type": "PE",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "2019-04-11T20:18:48.596799",
#     "endts_uts": 1555013928596799385,
#     "file.fd": 3,
#     "file.newpath": "",
#     "file.openflags": 262,
#     "file.path": "/dev/null",
#     "file.type": "f",
#     "filename": "",
#     "flow.rbytes": 0,
#     "flow.rops": 0,
#     "flow.wbytes": 0,
#     "flow.wops": 0,
#     "net.dip": "",
#     "net.dport": null,
#     "net.proto": "",
#     "net.sip": "",
#     "net.sport": null,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "O       C  ",
#     "opflags_bitmap": 1152,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "/usr/bin/healthcheck.sh",
#     "pproc.createts": 1555013928591289749,
#     "pproc.entry": "",
#     "pproc.exe": "/usr/bin/healthcheck.sh",
#     "pproc.gid": 0,
#     "pproc.group": "root",
#     "pproc.pid": 17064,
#     "pproc.tty": false,
#     "pproc.uid": 0,
#     "pproc.user": "root",
#     "proc.args": "/usr/bin/healthcheck.sh",
#     "proc.createts": 1555013928596730857,
#     "proc.entry": "",
#     "proc.exe": "/usr/bin/healthcheck.sh",
#     "proc.gid": 0,
#     "proc.group": "root",
#     "proc.pid": 17065,
#     "proc.tid": 17065,
#     "proc.tty": false,
#     "proc.uid": 0,
#     "proc.user": "root",
#     "res": "/dev/null",
#     "ret": null,
#     "schema": 1000,
#     "state": "REUP",
#     "ts": "2019-04-11T20:18:48.596793",
#     "ts_uts": 1555013928596793282,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "",
#     "endts_uts": null,
#     "file.fd": "",
#     "file.newpath": "",
#     "file.openflags": "",
#     "file.path": "",
#     "file.type": "",
#     "filename": "",
#     "flow.rbytes": null,
#     "flow.rops": null,
#     "flow.wbytes": null,
#     "flow.wops": null,
#     "net.dip": "",
#     "net.dport": null,
#     "net.proto": "",
#     "net.sip": "",
#     "net.sport": null,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "EXEC",
#     "opflags_bitmap": 2,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "/usr/bin/healthcheck.sh",
#     "pproc.createts": 1555013928591289749,
#     "pproc.entry": "",
#     "pproc.exe": "/usr/bin/healthcheck.sh",
#     "pproc.gid": 0,
#     "pproc.group": "root",
#     "pproc.pid": 17064,
#     "pproc.tty": false,
#     "pproc.uid": 0,
#     "pproc.user": "root",
#     "proc.args": "-nplt",
#     "proc.createts": 1555013928596730857,
#     "proc.entry": "",
#     "proc.exe": "/bin/netstat",
#     "proc.gid": 0,
#     "proc.group": "root",
#     "proc.pid": 17065,
#     "proc.tid": 17065,
#     "proc.tty": false,
#     "proc.uid": 0,
#     "proc.user": "root",
#     "res": "",
#     "ret": 0,
#     "schema": 1000,
#     "state": "MODIFIED",
#     "ts": "2019-04-11T20:18:48.596908",
#     "ts_uts": 1555013928596907661,
#     "type": "PE",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "2019-04-11T20:18:48.597466",
#     "endts_uts": 1555013928597466279,
#     "file.fd": 4,
#     "file.newpath": "",
#     "file.openflags": 1,
#     "file.path": "/proc/1/cmdline",
#     "file.type": "f",
#     "filename": "",
#     "flow.rbytes": 19,
#     "flow.rops": 2,
#     "flow.wbytes": 0,
#     "flow.wops": 0,
#     "net.dip": "",
#     "net.dport": null,
#     "net.proto": "",
#     "net.sip": "",
#     "net.sport": null,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "O   R   C  ",
#     "opflags_bitmap": 1408,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "/usr/bin/healthcheck.sh",
#     "pproc.createts": 1555013928591289749,
#     "pproc.entry": "",
#     "pproc.exe": "/usr/bin/healthcheck.sh",
#     "pproc.gid": 0,
#     "pproc.group": "root",
#     "pproc.pid": 17064,
#     "pproc.tty": false,
#     "pproc.uid": 0,
#     "pproc.user": "root",
#     "proc.args": "-nplt",
#     "proc.createts": 1555013928596730857,
#     "proc.entry": "",
#     "proc.exe": "/bin/netstat",
#     "proc.gid": 0,
#     "proc.group": "root",
#     "proc.pid": 17065,
#     "proc.tid": 17065,
#     "proc.tty": false,
#     "proc.uid": 0,
#     "proc.user": "root",
#     "res": "/proc/1/cmdline",
#     "ret": null,
#     "schema": 1000,
#     "state": "MODIFIED",
#     "ts": "2019-04-11T20:18:48.597453",
#     "ts_uts": 1555013928597453390,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "2019-04-11T20:18:48.597549",
#     "endts_uts": 1555013928597549119,
#     "file.fd": 4,
#     "file.newpath": "",
#     "file.openflags": 5121,
#     "file.path": "/proc/1/fd",
#     "file.type": "d",
#     "filename": "",
#     "flow.rbytes": 0,
#     "flow.rops": 0,
#     "flow.wbytes": 0,
#     "flow.wops": 0,
#     "net.dip": "",
#     "net.dport": null,
#     "net.proto": "",
#     "net.sip": "",
#     "net.sport": null,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "O       C  ",
#     "opflags_bitmap": 1152,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "/usr/bin/healthcheck.sh",
#     "pproc.createts": 1555013928591289749,
#     "pproc.entry": "",
#     "pproc.exe": "/usr/bin/healthcheck.sh",
#     "pproc.gid": 0,
#     "pproc.group": "root",
#     "pproc.pid": 17064,
#     "pproc.tty": false,
#     "pproc.uid": 0,
#     "pproc.user": "root",
#     "proc.args": "-nplt",
#     "proc.createts": 1555013928596730857,
#     "proc.entry": "",
#     "proc.exe": "/bin/netstat",
#     "proc.gid": 0,
#     "proc.group": "root",
#     "proc.pid": 17065,
#     "proc.tid": 17065,
#     "proc.tty": false,
#     "proc.uid": 0,
#     "proc.user": "root",
#     "res": "/proc/1/fd",
#     "ret": null,
#     "schema": 1000,
#     "state": "MODIFIED",
#     "ts": "2019-04-11T20:18:48.597475",
#     "ts_uts": 1555013928597474989,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "2019-04-11T20:18:48.597566",
#     "endts_uts": 1555013928597565759,
#     "file.fd": 4,
#     "file.newpath": "",
#     "file.openflags": 1,
#     "file.path": "/proc/437/cmdline",
#     "file.type": "f",
#     "filename": "",
#     "flow.rbytes": 35,
#     "flow.rops": 2,
#     "flow.wbytes": 0,
#     "flow.wops": 0,
#     "net.dip": "",
#     "net.dport": null,
#     "net.proto": "",
#     "net.sip": "",
#     "net.sport": null,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "O   R   C  ",
#     "opflags_bitmap": 1408,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "/usr/bin/healthcheck.sh",
#     "pproc.createts": 1555013928591289749,
#     "pproc.entry": "",
#     "pproc.exe": "/usr/bin/healthcheck.sh",
#     "pproc.gid": 0,
#     "pproc.group": "root",
#     "pproc.pid": 17064,
#     "pproc.tty": false,
#     "pproc.uid": 0,
#     "pproc.user": "root",
#     "proc.args": "-nplt",
#     "proc.createts": 1555013928596730857,
#     "proc.entry": "",
#     "proc.exe": "/bin/netstat",
#     "proc.gid": 0,
#     "proc.group": "root",
#     "proc.pid": 17065,
#     "proc.tid": 17065,
#     "proc.tty": false,
#     "proc.uid": 0,
#     "proc.user": "root",
#     "res": "/proc/437/cmdline",
#     "ret": null,
#     "schema": 1000,
#     "state": "MODIFIED",
#     "ts": "2019-04-11T20:18:48.597559",
#     "ts_uts": 1555013928597559351,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "2019-04-11T20:18:48.597605",
#     "endts_uts": 1555013928597605365,
#     "file.fd": 4,
#     "file.newpath": "",
#     "file.openflags": 5121,
#     "file.path": "/proc/437/fd",
#     "file.type": "d",
#     "filename": "",
#     "flow.rbytes": 0,
#     "flow.rops": 0,
#     "flow.wbytes": 0,
#     "flow.wops": 0,
#     "net.dip": "",
#     "net.dport": null,
#     "net.proto": "",
#     "net.sip": "",
#     "net.sport": null,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "O       C  ",
#     "opflags_bitmap": 1152,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "/usr/bin/healthcheck.sh",
#     "pproc.createts": 1555013928591289749,
#     "pproc.entry": "",
#     "pproc.exe": "/usr/bin/healthcheck.sh",
#     "pproc.gid": 0,
#     "pproc.group": "root",
#     "pproc.pid": 17064,
#     "pproc.tty": false,
#     "pproc.uid": 0,
#     "pproc.user": "root",
#     "proc.args": "-nplt",
#     "proc.createts": 1555013928596730857,
#     "proc.entry": "",
#     "proc.exe": "/bin/netstat",
#     "proc.gid": 0,
#     "proc.group": "root",
#     "proc.pid": 17065,
#     "proc.tid": 17065,
#     "proc.tty": false,
#     "proc.uid": 0,
#     "proc.user": "root",
#     "res": "/proc/437/fd",
#     "ret": null,
#     "schema": 1000,
#     "state": "MODIFIED",
#     "ts": "2019-04-11T20:18:48.597574",
#     "ts_uts": 1555013928597573734,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "2019-04-11T20:18:48.597620",
#     "endts_uts": 1555013928597619363,
#     "file.fd": 4,
#     "file.newpath": "",
#     "file.openflags": 1,
#     "file.path": "/proc/441/cmdline",
#     "file.type": "f",
#     "filename": "",
#     "flow.rbytes": 32,
#     "flow.rops": 2,
#     "flow.wbytes": 0,
#     "flow.wops": 0,
#     "net.dip": "",
#     "net.dport": null,
#     "net.proto": "",
#     "net.sip": "",
#     "net.sport": null,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "O   R   C  ",
#     "opflags_bitmap": 1408,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "/usr/bin/healthcheck.sh",
#     "pproc.createts": 1555013928591289749,
#     "pproc.entry": "",
#     "pproc.exe": "/usr/bin/healthcheck.sh",
#     "pproc.gid": 0,
#     "pproc.group": "root",
#     "pproc.pid": 17064,
#     "pproc.tty": false,
#     "pproc.uid": 0,
#     "pproc.user": "root",
#     "proc.args": "-nplt",
#     "proc.createts": 1555013928596730857,
#     "proc.entry": "",
#     "proc.exe": "/bin/netstat",
#     "proc.gid": 0,
#     "proc.group": "root",
#     "proc.pid": 17065,
#     "proc.tid": 17065,
#     "proc.tty": false,
#     "proc.uid": 0,
#     "proc.user": "root",
#     "res": "/proc/441/cmdline",
#     "ret": null,
#     "schema": 1000,
#     "state": "MODIFIED",
#     "ts": "2019-04-11T20:18:48.597614",
#     "ts_uts": 1555013928597613855,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "2019-04-11T20:18:48.597674",
#     "endts_uts": 1555013928597673816,
#     "file.fd": 4,
#     "file.newpath": "",
#     "file.openflags": 5121,
#     "file.path": "/proc/441/fd",
#     "file.type": "d",
#     "filename": "",
#     "flow.rbytes": 0,
#     "flow.rops": 0,
#     "flow.wbytes": 0,
#     "flow.wops": 0,
#     "net.dip": "",
#     "net.dport": null,
#     "net.proto": "",
#     "net.sip": "",
#     "net.sport": null,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "O       C  ",
#     "opflags_bitmap": 1152,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "/usr/bin/healthcheck.sh",
#     "pproc.createts": 1555013928591289749,
#     "pproc.entry": "",
#     "pproc.exe": "/usr/bin/healthcheck.sh",
#     "pproc.gid": 0,
#     "pproc.group": "root",
#     "pproc.pid": 17064,
#     "pproc.tty": false,
#     "pproc.uid": 0,
#     "pproc.user": "root",
#     "proc.args": "-nplt",
#     "proc.createts": 1555013928596730857,
#     "proc.entry": "",
#     "proc.exe": "/bin/netstat",
#     "proc.gid": 0,
#     "proc.group": "root",
#     "proc.pid": 17065,
#     "proc.tid": 17065,
#     "proc.tty": false,
#     "proc.uid": 0,
#     "proc.user": "root",
#     "res": "/proc/441/fd",
#     "ret": null,
#     "schema": 1000,
#     "state": "MODIFIED",
#     "ts": "2019-04-11T20:18:48.597627",
#     "ts_uts": 1555013928597627388,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "2019-04-11T20:18:48.597687",
#     "endts_uts": 1555013928597687442,
#     "file.fd": 4,
#     "file.newpath": "",
#     "file.openflags": 1,
#     "file.path": "/proc/442/cmdline",
#     "file.type": "f",
#     "filename": "",
#     "flow.rbytes": 32,
#     "flow.rops": 2,
#     "flow.wbytes": 0,
#     "flow.wops": 0,
#     "net.dip": "",
#     "net.dport": null,
#     "net.proto": "",
#     "net.sip": "",
#     "net.sport": null,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "O   R   C  ",
#     "opflags_bitmap": 1408,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "/usr/bin/healthcheck.sh",
#     "pproc.createts": 1555013928591289749,
#     "pproc.entry": "",
#     "pproc.exe": "/usr/bin/healthcheck.sh",
#     "pproc.gid": 0,
#     "pproc.group": "root",
#     "pproc.pid": 17064,
#     "pproc.tty": false,
#     "pproc.uid": 0,
#     "pproc.user": "root",
#     "proc.args": "-nplt",
#     "proc.createts": 1555013928596730857,
#     "proc.entry": "",
#     "proc.exe": "/bin/netstat",
#     "proc.gid": 0,
#     "proc.group": "root",
#     "proc.pid": 17065,
#     "proc.tid": 17065,
#     "proc.tty": false,
#     "proc.uid": 0,
#     "proc.user": "root",
#     "res": "/proc/442/cmdline",
#     "ret": null,
#     "schema": 1000,
#     "state": "MODIFIED",
#     "ts": "2019-04-11T20:18:48.597682",
#     "ts_uts": 1555013928597681545,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "2019-04-11T20:18:48.597725",
#     "endts_uts": 1555013928597724940,
#     "file.fd": 4,
#     "file.newpath": "",
#     "file.openflags": 5121,
#     "file.path": "/proc/442/fd",
#     "file.type": "d",
#     "filename": "",
#     "flow.rbytes": 0,
#     "flow.rops": 0,
#     "flow.wbytes": 0,
#     "flow.wops": 0,
#     "net.dip": "",
#     "net.dport": null,
#     "net.proto": "",
#     "net.sip": "",
#     "net.sport": null,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "O       C  ",
#     "opflags_bitmap": 1152,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "/usr/bin/healthcheck.sh",
#     "pproc.createts": 1555013928591289749,
#     "pproc.entry": "",
#     "pproc.exe": "/usr/bin/healthcheck.sh",
#     "pproc.gid": 0,
#     "pproc.group": "root",
#     "pproc.pid": 17064,
#     "pproc.tty": false,
#     "pproc.uid": 0,
#     "pproc.user": "root",
#     "proc.args": "-nplt",
#     "proc.createts": 1555013928596730857,
#     "proc.entry": "",
#     "proc.exe": "/bin/netstat",
#     "proc.gid": 0,
#     "proc.group": "root",
#     "proc.pid": 17065,
#     "proc.tid": 17065,
#     "proc.tty": false,
#     "proc.uid": 0,
#     "proc.user": "root",
#     "res": "/proc/442/fd",
#     "ret": null,
#     "schema": 1000,
#     "state": "MODIFIED",
#     "ts": "2019-04-11T20:18:48.597695",
#     "ts_uts": 1555013928597694986,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "2019-04-11T20:18:48.597738",
#     "endts_uts": 1555013928597737753,
#     "file.fd": 4,
#     "file.newpath": "",
#     "file.openflags": 1,
#     "file.path": "/proc/443/cmdline",
#     "file.type": "f",
#     "filename": "",
#     "flow.rbytes": 14,
#     "flow.rops": 2,
#     "flow.wbytes": 0,
#     "flow.wops": 0,
#     "net.dip": "",
#     "net.dport": null,
#     "net.proto": "",
#     "net.sip": "",
#     "net.sport": null,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "O   R   C  ",
#     "opflags_bitmap": 1408,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "/usr/bin/healthcheck.sh",
#     "pproc.createts": 1555013928591289749,
#     "pproc.entry": "",
#     "pproc.exe": "/usr/bin/healthcheck.sh",
#     "pproc.gid": 0,
#     "pproc.group": "root",
#     "pproc.pid": 17064,
#     "pproc.tty": false,
#     "pproc.uid": 0,
#     "pproc.user": "root",
#     "proc.args": "-nplt",
#     "proc.createts": 1555013928596730857,
#     "proc.entry": "",
#     "proc.exe": "/bin/netstat",
#     "proc.gid": 0,
#     "proc.group": "root",
#     "proc.pid": 17065,
#     "proc.tid": 17065,
#     "proc.tty": false,
#     "proc.uid": 0,
#     "proc.user": "root",
#     "res": "/proc/443/cmdline",
#     "ret": null,
#     "schema": 1000,
#     "state": "MODIFIED",
#     "ts": "2019-04-11T20:18:48.597733",
#     "ts_uts": 1555013928597732752,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "2019-04-11T20:18:48.597788",
#     "endts_uts": 1555013928597788110,
#     "file.fd": 4,
#     "file.newpath": "",
#     "file.openflags": 5121,
#     "file.path": "/proc/443/fd",
#     "file.type": "d",
#     "filename": "",
#     "flow.rbytes": 0,
#     "flow.rops": 0,
#     "flow.wbytes": 0,
#     "flow.wops": 0,
#     "net.dip": "",
#     "net.dport": null,
#     "net.proto": "",
#     "net.sip": "",
#     "net.sport": null,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "O       C  ",
#     "opflags_bitmap": 1152,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "/usr/bin/healthcheck.sh",
#     "pproc.createts": 1555013928591289749,
#     "pproc.entry": "",
#     "pproc.exe": "/usr/bin/healthcheck.sh",
#     "pproc.gid": 0,
#     "pproc.group": "root",
#     "pproc.pid": 17064,
#     "pproc.tty": false,
#     "pproc.uid": 0,
#     "pproc.user": "root",
#     "proc.args": "-nplt",
#     "proc.createts": 1555013928596730857,
#     "proc.entry": "",
#     "proc.exe": "/bin/netstat",
#     "proc.gid": 0,
#     "proc.group": "root",
#     "proc.pid": 17065,
#     "proc.tid": 17065,
#     "proc.tty": false,
#     "proc.uid": 0,
#     "proc.user": "root",
#     "res": "/proc/443/fd",
#     "ret": null,
#     "schema": 1000,
#     "state": "MODIFIED",
#     "ts": "2019-04-11T20:18:48.597745",
#     "ts_uts": 1555013928597745452,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "2019-04-11T20:18:48.597805",
#     "endts_uts": 1555013928597804894,
#     "file.fd": 4,
#     "file.newpath": "",
#     "file.openflags": 1,
#     "file.path": "/proc/444/cmdline",
#     "file.type": "f",
#     "filename": "",
#     "flow.rbytes": 60,
#     "flow.rops": 2,
#     "flow.wbytes": 0,
#     "flow.wops": 0,
#     "net.dip": "",
#     "net.dport": null,
#     "net.proto": "",
#     "net.sip": "",
#     "net.sport": null,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "O   R   C  ",
#     "opflags_bitmap": 1408,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "/usr/bin/healthcheck.sh",
#     "pproc.createts": 1555013928591289749,
#     "pproc.entry": "",
#     "pproc.exe": "/usr/bin/healthcheck.sh",
#     "pproc.gid": 0,
#     "pproc.group": "root",
#     "pproc.pid": 17064,
#     "pproc.tty": false,
#     "pproc.uid": 0,
#     "pproc.user": "root",
#     "proc.args": "-nplt",
#     "proc.createts": 1555013928596730857,
#     "proc.entry": "",
#     "proc.exe": "/bin/netstat",
#     "proc.gid": 0,
#     "proc.group": "root",
#     "proc.pid": 17065,
#     "proc.tid": 17065,
#     "proc.tty": false,
#     "proc.uid": 0,
#     "proc.user": "root",
#     "res": "/proc/444/cmdline",
#     "ret": null,
#     "schema": 1000,
#     "state": "MODIFIED",
#     "ts": "2019-04-11T20:18:48.597800",
#     "ts_uts": 1555013928597799361,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "2019-04-11T20:18:48.597850",
#     "endts_uts": 1555013928597850273,
#     "file.fd": 4,
#     "file.newpath": "",
#     "file.openflags": 5121,
#     "file.path": "/proc/444/fd",
#     "file.type": "d",
#     "filename": "",
#     "flow.rbytes": 0,
#     "flow.rops": 0,
#     "flow.wbytes": 0,
#     "flow.wops": 0,
#     "net.dip": "",
#     "net.dport": null,
#     "net.proto": "",
#     "net.sip": "",
#     "net.sport": null,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "O       C  ",
#     "opflags_bitmap": 1152,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "/usr/bin/healthcheck.sh",
#     "pproc.createts": 1555013928591289749,
#     "pproc.entry": "",
#     "pproc.exe": "/usr/bin/healthcheck.sh",
#     "pproc.gid": 0,
#     "pproc.group": "root",
#     "pproc.pid": 17064,
#     "pproc.tty": false,
#     "pproc.uid": 0,
#     "pproc.user": "root",
#     "proc.args": "-nplt",
#     "proc.createts": 1555013928596730857,
#     "proc.entry": "",
#     "proc.exe": "/bin/netstat",
#     "proc.gid": 0,
#     "proc.group": "root",
#     "proc.pid": 17065,
#     "proc.tid": 17065,
#     "proc.tty": false,
#     "proc.uid": 0,
#     "proc.user": "root",
#     "res": "/proc/444/fd",
#     "ret": null,
#     "schema": 1000,
#     "state": "MODIFIED",
#     "ts": "2019-04-11T20:18:48.597814",
#     "ts_uts": 1555013928597814044,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "2019-04-11T20:18:48.597853",
#     "endts_uts": 1555013928597852918,
#     "file.fd": 3,
#     "file.newpath": "",
#     "file.openflags": 5121,
#     "file.path": "/proc",
#     "file.type": "d",
#     "filename": "",
#     "flow.rbytes": 0,
#     "flow.rops": 0,
#     "flow.wbytes": 0,
#     "flow.wops": 0,
#     "net.dip": "",
#     "net.dport": null,
#     "net.proto": "",
#     "net.sip": "",
#     "net.sport": null,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "O       C  ",
#     "opflags_bitmap": 1152,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "/usr/bin/healthcheck.sh",
#     "pproc.createts": 1555013928591289749,
#     "pproc.entry": "",
#     "pproc.exe": "/usr/bin/healthcheck.sh",
#     "pproc.gid": 0,
#     "pproc.group": "root",
#     "pproc.pid": 17064,
#     "pproc.tty": false,
#     "pproc.uid": 0,
#     "pproc.user": "root",
#     "proc.args": "-nplt",
#     "proc.createts": 1555013928596730857,
#     "proc.entry": "",
#     "proc.exe": "/bin/netstat",
#     "proc.gid": 0,
#     "proc.group": "root",
#     "proc.pid": 17065,
#     "proc.tid": 17065,
# ...
#     "proc.pid": 13144,
#     "proc.tid": 13144,
#     "proc.tty": false,
#     "proc.uid": 0,
#     "proc.user": "root",
#     "res": "/data/.minio.sys/buckets/play/tcpclientserver/fs.json",
#     "ret": null,
#     "schema": 1000,
#     "state": "REUP",
#     "ts": "2019-04-11T20:18:50.207677",
#     "ts_uts": 1555013930207676814,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "2019-04-11T20:18:50.208770",
#     "endts_uts": 1555013930208769859,
#     "file.fd": 6,
#     "file.newpath": "",
#     "file.openflags": "",
#     "file.path": "",
#     "file.type": "",
#     "filename": "",
#     "flow.rbytes": 1537,
#     "flow.rops": 6,
#     "flow.wbytes": 0,
#     "flow.wops": 0,
#     "net.dip": "172.17.0.4",
#     "net.dport": 9000,
#     "net.proto": 6,
#     "net.sip": "172.17.0.5",
#     "net.sport": 52942,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": " A  R    T ",
#     "opflags_bitmap": 2336,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "-namespace moby -workdir /var/lib/docker/containerd/daemon/io.containerd.runtime.v1.linux/moby/8661fade8683f3269e07346e7ebace7eef622fc0a9c57677cf4a8318237ebfcc -address /var/run/docker/containerd/docker-containerd.sock -containerd-binary /usr/bin/docker-containerd -runtime-root /var/run/docker/runtime-runc",
#     "pproc.createts": 0,
#     "pproc.entry": "",
#     "pproc.exe": "/usr/bin/docker-containerd-shim",
#     "pproc.gid": 0,
#     "pproc.group": "root",
#     "pproc.pid": 13116,
#     "pproc.tty": false,
#     "pproc.uid": 0,
#     "pproc.user": "root",
#     "proc.args": "server /data",
#     "proc.createts": 0,
#     "proc.entry": "",
#     "proc.exe": "/usr/bin/minio",
#     "proc.gid": 0,
#     "proc.group": "root",
#     "proc.pid": 13144,
#     "proc.tid": 13185,
#     "proc.tty": false,
#     "proc.uid": 0,
#     "proc.user": "root",
#     "res": "172.17.0.5:52942-172.17.0.4:9000",
#     "ret": null,
#     "schema": 1000,
#     "state": "REUP",
#     "ts": "2019-04-11T20:18:50.203071",
#     "ts_uts": 1555013930203070983,
#     "type": "NF",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "2019-04-11T20:18:50.208770",
#     "endts_uts": 1555013930208769859,
#     "file.fd": 6,
#     "file.newpath": "",
#     "file.openflags": "",
#     "file.path": "",
#     "file.type": "",
#     "filename": "",
#     "flow.rbytes": 482,
#     "flow.rops": 2,
#     "flow.wbytes": 11727,
#     "flow.wops": 3,
#     "net.dip": "172.17.0.4",
#     "net.dport": 9000,
#     "net.proto": 6,
#     "net.sip": "172.17.0.5",
#     "net.sport": 52942,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "   WR    T ",
#     "opflags_bitmap": 2816,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "-namespace moby -workdir /var/lib/docker/containerd/daemon/io.containerd.runtime.v1.linux/moby/8661fade8683f3269e07346e7ebace7eef622fc0a9c57677cf4a8318237ebfcc -address /var/run/docker/containerd/docker-containerd.sock -containerd-binary /usr/bin/docker-containerd -runtime-root /var/run/docker/runtime-runc",
#     "pproc.createts": 0,
#     "pproc.entry": "",
#     "pproc.exe": "/usr/bin/docker-containerd-shim",
#     "pproc.gid": 0,
#     "pproc.group": "root",
#     "pproc.pid": 13116,
#     "pproc.tty": false,
#     "pproc.uid": 0,
#     "pproc.user": "root",
#     "proc.args": "server /data",
#     "proc.createts": 0,
#     "proc.entry": "",
#     "proc.exe": "/usr/bin/minio",
#     "proc.gid": 0,
#     "proc.group": "root",
#     "proc.pid": 13144,
#     "proc.tid": 13179,
#     "proc.tty": false,
#     "proc.uid": 0,
#     "proc.user": "root",
#     "res": "172.17.0.5:52942-172.17.0.4:9000",
#     "ret": null,
#     "schema": 1000,
#     "state": "REUP",
#     "ts": "2019-04-11T20:18:50.203867",
#     "ts_uts": 1555013930203867227,
#     "type": "NF",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "2019-04-11T20:18:50.208770",
#     "endts_uts": 1555013930208769859,
#     "file.fd": 6,
#     "file.newpath": "",
#     "file.openflags": "",
#     "file.path": "",
#     "file.type": "",
#     "filename": "",
#     "flow.rbytes": 0,
#     "flow.rops": 1,
#     "flow.wbytes": 13967,
#     "flow.wops": 4,
#     "net.dip": "172.17.0.4",
#     "net.dport": 9000,
#     "net.proto": 6,
#     "net.sip": "172.17.0.5",
#     "net.sport": 52942,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "   WR   C  ",
#     "opflags_bitmap": 1792,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "-namespace moby -workdir /var/lib/docker/containerd/daemon/io.containerd.runtime.v1.linux/moby/8661fade8683f3269e07346e7ebace7eef622fc0a9c57677cf4a8318237ebfcc -address /var/run/docker/containerd/docker-containerd.sock -containerd-binary /usr/bin/docker-containerd -runtime-root /var/run/docker/runtime-runc",
#     "pproc.createts": 0,
#     "pproc.entry": "",
#     "pproc.exe": "/usr/bin/docker-containerd-shim",
#     "pproc.gid": 0,
#     "pproc.group": "root",
#     "pproc.pid": 13116,
#     "pproc.tty": false,
#     "pproc.uid": 0,
#     "pproc.user": "root",
#     "proc.args": "server /data",
#     "proc.createts": 0,
#     "proc.entry": "",
#     "proc.exe": "/usr/bin/minio",
#     "proc.gid": 0,
#     "proc.group": "root",
#     "proc.pid": 13144,
#     "proc.tid": 13144,
#     "proc.tty": false,
#     "proc.uid": 0,
#     "proc.user": "root",
#     "res": "172.17.0.5:52942-172.17.0.4:9000",
#     "ret": null,
#     "schema": 1000,
#     "state": "REUP",
#     "ts": "2019-04-11T20:18:50.205752",
#     "ts_uts": 1555013930205751818,
#     "type": "NF",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "2019-04-11T20:18:50.209216",
#     "endts_uts": 1555013930209216373,
#     "file.fd": 7,
#     "file.newpath": "",
#     "file.openflags": 4241,
#     "file.path": "/data/.minio.sys/buckets/play/tcpclientserver/fs.json",
#     "file.type": "f",
#     "filename": "",
#     "flow.rbytes": 168,
#     "flow.rops": 1,
#     "flow.wbytes": 0,
#     "flow.wops": 0,
#     "net.dip": "",
#     "net.dport": null,
#     "net.proto": "",
#     "net.sip": "",
#     "net.sport": null,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "O   R   C  ",
#     "opflags_bitmap": 1408,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "-namespace moby -workdir /var/lib/docker/containerd/daemon/io.containerd.runtime.v1.linux/moby/8661fade8683f3269e07346e7ebace7eef622fc0a9c57677cf4a8318237ebfcc -address /var/run/docker/containerd/docker-containerd.sock -containerd-binary /usr/bin/docker-containerd -runtime-root /var/run/docker/runtime-runc",
#     "pproc.createts": 0,
#     "pproc.entry": "",
#     "pproc.exe": "/usr/bin/docker-containerd-shim",
#     "pproc.gid": 0,
#     "pproc.group": "root",
#     "pproc.pid": 13116,
#     "pproc.tty": false,
#     "pproc.uid": 0,
#     "pproc.user": "root",
#     "proc.args": "server /data",
#     "proc.createts": 0,
#     "proc.entry": "",
#     "proc.exe": "/usr/bin/minio",
#     "proc.gid": 0,
#     "proc.group": "root",
#     "proc.pid": 13144,
#     "proc.tid": 13185,
#     "proc.tty": false,
#     "proc.uid": 0,
#     "proc.user": "root",
#     "res": "/data/.minio.sys/buckets/play/tcpclientserver/fs.json",
#     "ret": null,
#     "schema": 1000,
#     "state": "REUP",
#     "ts": "2019-04-11T20:18:50.209183",
#     "ts_uts": 1555013930209183475,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "2019-04-11T20:18:50.212138",
#     "endts_uts": 1555013930212138203,
#     "file.fd": 8,
#     "file.newpath": "",
#     "file.openflags": 4097,
#     "file.path": "/data/play/tcpclientserver",
#     "file.type": "f",
#     "filename": "",
#     "flow.rbytes": 12571,
#     "flow.rops": 1,
#     "flow.wbytes": 0,
#     "flow.wops": 0,
#     "net.dip": "",
#     "net.dport": null,
#     "net.proto": "",
#     "net.sip": "",
#     "net.sport": null,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "O   R   C  ",
#     "opflags_bitmap": 1408,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "-namespace moby -workdir /var/lib/docker/containerd/daemon/io.containerd.runtime.v1.linux/moby/8661fade8683f3269e07346e7ebace7eef622fc0a9c57677cf4a8318237ebfcc -address /var/run/docker/containerd/docker-containerd.sock -containerd-binary /usr/bin/docker-containerd -runtime-root /var/run/docker/runtime-runc",
#     "pproc.createts": 0,
#     "pproc.entry": "",
#     "pproc.exe": "/usr/bin/docker-containerd-shim",
#     "pproc.gid": 0,
#     "pproc.group": "root",
#     "pproc.pid": 13116,
#     "pproc.tty": false,
#     "pproc.uid": 0,
#     "pproc.user": "root",
#     "proc.args": "server /data",
#     "proc.createts": 0,
#     "proc.entry": "",
#     "proc.exe": "/usr/bin/minio",
#     "proc.gid": 0,
#     "proc.group": "root",
#     "proc.pid": 13144,
#     "proc.tid": 13185,
#     "proc.tty": false,
#     "proc.uid": 0,
#     "proc.user": "root",
#     "res": "/data/play/tcpclientserver",
#     "ret": null,
#     "schema": 1000,
#     "state": "REUP",
#     "ts": "2019-04-11T20:18:50.209329",
#     "ts_uts": 1555013930209329015,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "2019-04-11T20:18:50.212146",
#     "endts_uts": 1555013930212145589,
#     "file.fd": 7,
#     "file.newpath": "",
#     "file.openflags": 4241,
#     "file.path": "/data/.minio.sys/buckets/play/tcpclientserver/fs.json",
#     "file.type": "f",
#     "filename": "",
#     "flow.rbytes": 168,
#     "flow.rops": 1,
#     "flow.wbytes": 0,
#     "flow.wops": 0,
#     "net.dip": "",
#     "net.dport": null,
#     "net.proto": "",
#     "net.sip": "",
#     "net.sport": null,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "O   R   C  ",
#     "opflags_bitmap": 1408,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "-namespace moby -workdir /var/lib/docker/containerd/daemon/io.containerd.runtime.v1.linux/moby/8661fade8683f3269e07346e7ebace7eef622fc0a9c57677cf4a8318237ebfcc -address /var/run/docker/containerd/docker-containerd.sock -containerd-binary /usr/bin/docker-containerd -runtime-root /var/run/docker/runtime-runc",
#     "pproc.createts": 0,
#     "pproc.entry": "",
#     "pproc.exe": "/usr/bin/docker-containerd-shim",
#     "pproc.gid": 0,
#     "pproc.group": "root",
#     "pproc.pid": 13116,
#     "pproc.tty": false,
#     "pproc.uid": 0,
#     "pproc.user": "root",
#     "proc.args": "server /data",
#     "proc.createts": 0,
#     "proc.entry": "",
#     "proc.exe": "/usr/bin/minio",
#     "proc.gid": 0,
#     "proc.group": "root",
#     "proc.pid": 13144,
#     "proc.tid": 13185,
#     "proc.tty": false,
#     "proc.uid": 0,
#     "proc.user": "root",
#     "res": "/data/.minio.sys/buckets/play/tcpclientserver/fs.json",
#     "ret": null,
#     "schema": 1000,
#     "state": "REUP",
#     "ts": "2019-04-11T20:18:50.209297",
#     "ts_uts": 1555013930209297099,
#     "type": "FF",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "2019-04-11T20:18:50.212518",
#     "endts_uts": 1555013930212518268,
#     "file.fd": 6,
#     "file.newpath": "",
#     "file.openflags": "",
#     "file.path": "",
#     "file.type": "",
#     "filename": "",
#     "flow.rbytes": 537,
#     "flow.rops": 2,
#     "flow.wbytes": 0,
#     "flow.wops": 0,
#     "net.dip": "172.17.0.4",
#     "net.dport": 9000,
#     "net.proto": 6,
#     "net.sip": "172.17.0.5",
#     "net.sport": 52944,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": " A  R    T ",
#     "opflags_bitmap": 2336,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "-namespace moby -workdir /var/lib/docker/containerd/daemon/io.containerd.runtime.v1.linux/moby/8661fade8683f3269e07346e7ebace7eef622fc0a9c57677cf4a8318237ebfcc -address /var/run/docker/containerd/docker-containerd.sock -containerd-binary /usr/bin/docker-containerd -runtime-root /var/run/docker/runtime-runc",
#     "pproc.createts": 0,
#     "pproc.entry": "",
#     "pproc.exe": "/usr/bin/docker-containerd-shim",
#     "pproc.gid": 0,
#     "pproc.group": "root",
#     "pproc.pid": 13116,
#     "pproc.tty": false,
#     "pproc.uid": 0,
#     "pproc.user": "root",
#     "proc.args": "server /data",
#     "proc.createts": 0,
#     "proc.entry": "",
#     "proc.exe": "/usr/bin/minio",
#     "proc.gid": 0,
#     "proc.group": "root",
#     "proc.pid": 13144,
#     "proc.tid": 13179,
#     "proc.tty": false,
#     "proc.uid": 0,
#     "proc.user": "root",
#     "res": "172.17.0.5:52944-172.17.0.4:9000",
#     "ret": null,
#     "schema": 1000,
#     "state": "REUP",
#     "ts": "2019-04-11T20:18:50.208804",
#     "ts_uts": 1555013930208803615,
#     "type": "NF",
#     "version": "3"
#   },
#   {
#     "container.id": "8661fade8683",
#     "container.image": "minio/minio/latest",
#     "container.imageid": "3120d28bc5cab700ef2e78d932fbd6707a6891b38ed8b280ad794fe68fae9718",
#     "container.name": "minio",
#     "container.privileged": false,
#     "container.type": "CT_DOCKER",
#     "endts": "2019-04-11T20:18:50.212518",
#     "endts_uts": 1555013930212518268,
#     "file.fd": 6,
#     "file.newpath": "",
#     "file.openflags": "",
#     "file.path": "",
#     "file.type": "",
#     "filename": "",
#     "flow.rbytes": 0,
#     "flow.rops": 1,
#     "flow.wbytes": 12992,
#     "flow.wops": 2,
#     "net.dip": "172.17.0.4",
#     "net.dport": 9000,
#     "net.proto": 6,
#     "net.sip": "172.17.0.5",
#     "net.sport": 52944,
#     "node.id": "tests",
#     "node.ip": "",
#     "opflags": "   WR   C  ",
#     "opflags_bitmap": 1792,
#     "pf.nerrors": null,
#     "pf.nexits": null,
#     "pf.nthreads": null,
#     "pproc.args": "-namespace moby -workdir /var/lib/docker/containerd/daemon/io.containerd.runtime.v1.linux/moby/8661fade8683f3269e07346e7ebace7eef622fc0a9c57677cf4a8318237ebfcc -address /var/run/docker/containerd/docker-containerd.sock -containerd-binary /usr/bin/docker-containerd -runtime-root /var/run/docker/runtime-runc",
#     "pproc.createts": 0,
#     "pproc.entry": "",
#     "pproc.exe": "/usr/bin/docker-containerd-shim",
#     "pproc.gid": 0,
#     "pproc.group": "root",
#     "pproc.pid": 13116,
#     "pproc.tty": false,
#     "pproc.uid": 0,
#     "pproc.user": "root",
#     "proc.args": "server /data",
#     "proc.createts": 0,
#     "proc.entry": "",
#     "proc.exe": "/usr/bin/minio",
#     "proc.gid": 0,
#     "proc.group": "root",
#     "proc.pid": 13144,
#     "proc.tid": 13185,
#     "proc.tty": false,
#     "proc.uid": 0,
#     "proc.user": "root",
#     "res": "172.17.0.5:52944-172.17.0.4:9000",
#     "ret": null,
#     "schema": 1000,
#     "state": "REUP",
#     "ts": "2019-04-11T20:18:50.209523",
#     "ts_uts": 1555013930209523058,
#     "type": "NF",
#     "version": "3"
#   }
# ]

# %% [markdown]
# ## Query API

# %%
trace = '../../data/attacks/express/mon.1531776712.sf'
cols=['ts_uts', 'endts_uts', 'type', 'opflags', 'proc.pid', 'proc.tid', 'proc.exe', 'file.path', 'flow.rbytes', 'flow.wbytes', 'container.imageid']

# %%
# Initial indicator of compromise
reader = FlattenedSFReader(trace)
query = 'type = FF and file.type = f and opflags contains WRITE and proc.name pmatch (http_server_binaries)'
formatter = SFFormatter(reader, defs=['sfql/defs.yaml'])
df = formatter.toDataframe(expr=query, fields=cols)
df.head()
# Out:
#                 ts_uts            endts_uts type      opflags  proc.pid  \
# 0  1531776715030353952  1531776715030578781   FF     W     T       2025
#
#    proc.tid             proc.exe      file.path  flow.rbytes  flow.wbytes  \
# 0     12406  /usr/local/bin/node  /tmp/exfil.py            0         6537
#
#                                                   container.imageid
# 0  55f142ac5da7d234c7bba0662149e26bada9c6baaf504f632e13c840206fab7b

# %%
# Policies can also be defined and reused
reader = FlattenedSFReader(trace)
formatter = SFFormatter(reader, defs=['sfql/defs.yaml'])
df = formatter.toDataframe(expr='suspicious_webserver_writes', fields=cols)
df.head()
# Out:
#                 ts_uts            endts_uts type      opflags  proc.pid  \
# 0  1531776715030353952  1531776715030578781   FF     W     T       2025
#
#    proc.tid             proc.exe      file.path  flow.rbytes  flow.wbytes  \
# 0     12406  /usr/local/bin/node  /tmp/exfil.py            0         6537
#
#                                                   container.imageid
# 0  55f142ac5da7d234c7bba0662149e26bada9c6baaf504f632e13c840206fab7b

# %%
trace = '../../data/attacks/express/mon.1531776712.sf'
cols_=['ts_uts', 'type', 'opflags', 'pproc.pid', 'proc.pid', 'pproc.exe', 'proc.exe', 'proc.args']

# %%
# Finding all process executions involving suspicious script
reader = FlattenedSFReader(trace)
query = 'type = PE and opflags = EXEC and (proc.aname contains exfil.py or proc.args contains exfil.py or file.path contains exfil.py)'
formatter = SFFormatter(reader)
df = formatter.toDataframe(expr=query, fields=cols_)
df.head(20)
# Out:
#                  ts_uts type opflags  pproc.pid  proc.pid  \
# 0   1531776715041743005   PE    EXEC       2025     17753
# 1   1531776715049024767   PE    EXEC      17753     17754
# 2   1531776715077890260   PE    EXEC      17754     17757
# 3   1531776715078056634   PE    EXEC      17754     17757
# 4   1531776715078110412   PE    EXEC      17754     17757
# 5   1531776715078162793   PE    EXEC      17754     17757
# 6   1531776715078210871   PE    EXEC      17754     17757
# 7   1531776715078687969   PE    EXEC      17754     17757
# 8   1531776716574185341   PE    EXEC      17757     17758
# 9   1531776718037729035   PE    EXEC      17757     17767
# 10  1531776721816616574   PE    EXEC      13526     17819
# 11  1531776724236565898   PE    EXEC      17757     17826
# 12  1531776735465803137   PE    EXEC      17757     18005
# 13  1531776738136774803   PE    EXEC      17757     18043
# 14  1531776738141911192   PE    EXEC      17754     18062
# 15  1531776738142131579   PE    EXEC      17754     18062
# 16  1531776738142187946   PE    EXEC      17754     18062
# 17  1531776738142269667   PE    EXEC      17754     18062
# 18  1531776738142313320   PE    EXEC      17754     18062
# 19  1531776738142823237   PE    EXEC      17754     18062
#
#               pproc.exe                   proc.exe  \
# 0   /usr/local/bin/node                    /bin/sh
# 1               /bin/sh              /tmp/exfil.py
# 2         /tmp/exfil.py              /tmp/exfil.py
# 3         /tmp/exfil.py              /tmp/exfil.py
# 4         /tmp/exfil.py              /tmp/exfil.py
# 5         /tmp/exfil.py              /tmp/exfil.py
# 6         /tmp/exfil.py              /tmp/exfil.py
# 7         /tmp/exfil.py           /usr/bin/apt-get
# 8      /usr/bin/apt-get           /usr/bin/apt-get
# 9      /usr/bin/apt-get           /usr/bin/apt-get
# 10            /bin/bash                  /bin/more
# 11     /usr/bin/apt-get  /usr/lib/apt/methods/gpgv
# 12     /usr/bin/apt-get              /usr/bin/dpkg
# 13     /usr/bin/apt-get              /usr/bin/dpkg
# 14        /tmp/exfil.py              /tmp/exfil.py
# 15        /tmp/exfil.py              /tmp/exfil.py
# 16        /tmp/exfil.py              /tmp/exfil.py
# 17        /tmp/exfil.py              /tmp/exfil.py
# 18        /tmp/exfil.py              /tmp/exfil.py
# 19        /tmp/exfil.py           /usr/bin/apt-get
#
#                         proc.args
# 0             -c /tmp/exfil.py -a
# 1                /tmp/exfil.py -a
# 2                /tmp/exfil.py -a
# 3                /tmp/exfil.py -a
# 4                /tmp/exfil.py -a
# 5                /tmp/exfil.py -a
# 6                /tmp/exfil.py -a
# 7                          update
# 8   --print-foreign-architectures
# 9
# 10                       exfil.py
# 11
# 12  --print-foreign-architectures
# 13  --print-foreign-architectures
# 14               /tmp/exfil.py -a
# 15               /tmp/exfil.py -a
# 16               /tmp/exfil.py -a
# 17               /tmp/exfil.py -a
# 18               /tmp/exfil.py -a
# 19          install -y python-pip

# %%
_trace = '../../data/attacks/express/mon.1531776742.sf'
_cols=['ts_uts', 'type', 'opflags', 'proc.pid', 'pproc.exe', 'proc.exe', 'proc.args', 'net.sip', 'net.sport', 'net.dip', 'net.dport', 'flow.rbytes', 'flow.wbytes']

# %%
# Finding all network flows related to suspicious script
reader = FlattenedSFReader(_trace)
query = 'type = NF and (proc.aname contains exfil.py or proc.args contains exfil.py or file.path contains exfil.py)'
formatter = SFFormatter(reader)
df = formatter.toDataframe(expr=query, fields=_cols)

ax = flows[['ts_uts', 'flow.rbytes', 'flow.wbytes']].plot.bar(x='ts_uts', y=['flow.rbytes','flow.wbytes'], rot=45, figsize=(20,5))
ax.xaxis.set_major_locator(mdates.AutoDateLocator())
plt.gcf().autofmt_xdate()
plt.show()

# %%
# Summarizing sysflow types
reader = FlattenedSFReader(trace)
formatter = SFFormatter(reader)
df = formatter.toDataframe(fields=cols)
types = df.groupby(['type']).count()[['ts_uts']].rename(columns={"ts_uts": "count"}) 
pie = types.plot.pie(subplots=True)

# %%
# Rank ordering file operations
_df = df.replace('', np.nan).dropna(axis=0, how='any', subset=['file.path'])
paths = _df[cols].groupby(['file.path']).count()[['ts_uts']].rename(columns={"ts_uts": "count"})
paths.sort_values(by='count', ascending=False)
# Out:
#                                                                          count
# file.path
# /etc/ld.so.cache                                                            96
# /lib/x86_64-linux-gnu/libc.so.6                                             48
# /dev/null                                                                   20
# pipe:[66729332]                                                             18
# /etc/hosts                                                                  16
# ...                                                                        ...
# /var/lib/apt/lists/lock                                                      1
# /etc/services                                                                1
# /etc/apt/sources.list.d                                                      1
# /var/lib/apt/lists/deb.debian.org_debian_dists_jessie-updates_InRelease      1
# /tmp/malware.log                                                             1
#
# [915 rows x 1 columns]

# %% [markdown]
# ## Reader API
#
# **Note:** See [formatter.py](https://github.com/sysflow-telemetry/sf-apis/blob/master/py3/classes/sysflow/formatter.py) for a more advanced example of how to use the reader API.

# %%
import sysflow.utils as utils
from sysflow.objtypes import ObjectTypes
from IPython.display import display, HTML, Markdown

# %%
trace = '../../data/attacks/express/mon.1531776712.sf'

# %%
# Using the flattened reader to find initial indicator of compromise
reader = FlattenedSFReader(trace)
head = 20 # max number of records to print
for i, (objtype, header, cont, pproc, proc, files, evt, flow) in enumerate(reader):
    exe = proc.exe
    pid = proc.oid.hpid if proc else ''
    evflow = evt or flow
    tid = evflow.tid if evflow else ''
    opFlags = utils.getOpFlagsStr(evflow.opFlags) if evflow else '' 
    sTime = utils.getTimeStr(evflow.ts) if evflow else ''
    eTime = utils.getTimeStr(evflow.endTs) if flow else ''
    ret = evflow.ret if evt else ''
    res1 = ''
    if objtype == ObjectTypes.FILE_FLOW or objtype == ObjectTypes.FILE_EVT:
        res1 = files[0].path
    elif objtype == ObjectTypes.NET_FLOW:
        res1 = utils.getNetFlowStr(flow) 
    numBReads = evflow.numRRecvBytes if flow else ''
    numBWrites = evflow.numWSendBytes if flow else ''
    res2 = files[1].path if files and files[1] else ''
    cont = cont.id if cont else '' 
    display(Markdown("<span style=\"font-size:11pt;\">|{0:30}|{1:9}|{2:26}|{3:26}|{4:30}|{5:8}|{6:8}|</span>"
                     .format(exe, opFlags, sTime, eTime, res1, numBReads, numBWrites)))   
    if i == head:
        break
# Out:
# <span style="font-size:11pt;">|/usr/local/bin/node           |CLONE    |07/16/2018T21:31:52.370537|                          |                              |        |        |</span>
# <span style="font-size:11pt;">|/bin/dash                     |CLONE    |07/16/2018T21:31:52.370578|                          |                              |        |        |</span>
# <span style="font-size:11pt;">|/usr/local/bin/node           |        C  |07/16/2018T21:31:52.370611|07/16/2018T21:31:52.370611|                              |       0|       0|</span>
# <span style="font-size:11pt;">|/bin/sh                       |EXEC     |07/16/2018T21:31:52.371724|                          |                              |        |        |</span>
# <span style="font-size:11pt;">|/usr/local/bin/node           |    R   C  |07/16/2018T21:31:52.371749|07/16/2018T21:31:52.371752|                              |       0|       0|</span>
# <span style="font-size:11pt;">|/usr/local/bin/node           |        C  |07/16/2018T21:31:52.371756|07/16/2018T21:31:52.371756|                              |       0|       0|</span>
# <span style="font-size:11pt;">|/usr/local/bin/node           |        C  |07/16/2018T21:31:52.371763|07/16/2018T21:31:52.371763|                              |       0|       0|</span>
# <span style="font-size:11pt;">|/usr/local/bin/node           |        C  |07/16/2018T21:31:52.371766|07/16/2018T21:31:52.371766|                              |       0|       0|</span>
# <span style="font-size:11pt;">|/usr/local/bin/node           | A WR   C  |07/16/2018T21:31:52.366998|07/16/2018T21:31:52.372548|10.187.39.243:49824-172.30.106.116:3000|      95|     362|</span>
# <span style="font-size:11pt;">|/bin/sh                       |O       C  |07/16/2018T21:31:52.372761|07/16/2018T21:31:52.372772|/etc/ld.so.cache              |       0|       0|</span>
# <span style="font-size:11pt;">|/bin/sh                       |O   R   C  |07/16/2018T21:31:52.372787|07/16/2018T21:31:52.372832|/lib/x86_64-linux-gnu/libc.so.6|     832|       0|</span>
# <span style="font-size:11pt;">|/bin/sh                       |CLONE    |07/16/2018T21:31:52.373299|                          |                              |        |        |</span>
# <span style="font-size:11pt;">|/usr/bin/python2.7            |CLONE    |07/16/2018T21:31:52.373318|                          |                              |        |        |</span>
# <span style="font-size:11pt;">|/usr/bin/python               |EXEC     |07/16/2018T21:31:52.373715|                          |                              |        |        |</span>
# <span style="font-size:11pt;">|/usr/bin/python               |O       C  |07/16/2018T21:31:52.373802|07/16/2018T21:31:52.373813|/etc/ld.so.cache              |       0|       0|</span>
# <span style="font-size:11pt;">|/usr/bin/python               |O   R   C  |07/16/2018T21:31:52.373827|07/16/2018T21:31:52.373868|/lib/x86_64-linux-gnu/libpthread.so.0|     832|       0|</span>
# <span style="font-size:11pt;">|/usr/bin/python               |O   R   C  |07/16/2018T21:31:52.373882|07/16/2018T21:31:52.373912|/lib/x86_64-linux-gnu/libdl.so.2|     832|       0|</span>
# <span style="font-size:11pt;">|/usr/bin/python               |O   R   C  |07/16/2018T21:31:52.373924|07/16/2018T21:31:52.373957|/lib/x86_64-linux-gnu/libutil.so.1|     832|       0|</span>
# <span style="font-size:11pt;">|/usr/bin/python               |O   R   C  |07/16/2018T21:31:52.373969|07/16/2018T21:31:52.373996|/lib/x86_64-linux-gnu/libz.so.1|     832|       0|</span>
# <span style="font-size:11pt;">|/usr/bin/python               |O   R   C  |07/16/2018T21:31:52.374010|07/16/2018T21:31:52.374038|/lib/x86_64-linux-gnu/libm.so.6|     832|       0|</span>
# <span style="font-size:11pt;">|/usr/bin/python               |O   R   C  |07/16/2018T21:31:52.374051|07/16/2018T21:31:52.374089|/lib/x86_64-linux-gnu/libc.so.6|     832|       0|</span>
