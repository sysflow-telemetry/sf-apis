# %% [markdown]
# # SysFlow FloCon 2020 Talk Demo
# Talk presented at FloCon 2020. Please check [abstract and presentation slides](https://flocon2020.sched.com/event/VPW3/sysflow-scalable-system-telemetry-for-improved-security-analytics) at the conference website.

# %% [markdown]
# ![attack](figures/attack.png) <!-- .element height="200%" width="100%" -->

# %%
import sys, os, json
import numpy as np
import pandas as pd
pd.set_option('display.max_colwidth', 75)

# %%
from sysflow.reader import FlattenedSFReader
from sysflow.formatter import SFFormatter

# %%
trace = 'data/attacks/express/mon.1531776712.sf'
cols=['ts_uts', 'endts_uts', 'type', 'opflags', 'proc.pid', 'proc.tid', 'proc.exe', 'file.path', 'flow.rbytes', 'flow.wbytes', 'container.imageid']

# %%
def highlight_path(r):
    return ['background-color: yellow' if 'exfil' in r['file.path'] else ''] * len(cols)

# %%
# Initial indicator of compromise
reader = FlattenedSFReader(trace)
query = 'type = FF and file.type = f and opflags contains WRITE and proc.name pmatch (http_server_binaries)'
formatter = SFFormatter(reader, defs=['sfql/defs.yaml'])
df = formatter.toDataframe(expr=query, fields=cols)
df.style.apply(highlight_path, axis=1)
# Out:
# <style  type="text/css" >
#     #T_3337c6f8_3f96_11ea_81f9_0242ac110004row0_col0 {
#             background-color:  yellow;
#         }    #T_3337c6f8_3f96_11ea_81f9_0242ac110004row0_col1 {
#             background-color:  yellow;
#         }    #T_3337c6f8_3f96_11ea_81f9_0242ac110004row0_col2 {
#             background-color:  yellow;
#         }    #T_3337c6f8_3f96_11ea_81f9_0242ac110004row0_col3 {
#             background-color:  yellow;
#         }    #T_3337c6f8_3f96_11ea_81f9_0242ac110004row0_col4 {
#             background-color:  yellow;
#         }    #T_3337c6f8_3f96_11ea_81f9_0242ac110004row0_col5 {
#             background-color:  yellow;
#         }    #T_3337c6f8_3f96_11ea_81f9_0242ac110004row0_col6 {
#             background-color:  yellow;
#         }    #T_3337c6f8_3f96_11ea_81f9_0242ac110004row0_col7 {
#             background-color:  yellow;
#         }    #T_3337c6f8_3f96_11ea_81f9_0242ac110004row0_col8 {
#             background-color:  yellow;
#         }    #T_3337c6f8_3f96_11ea_81f9_0242ac110004row0_col9 {
#             background-color:  yellow;
#         }    #T_3337c6f8_3f96_11ea_81f9_0242ac110004row0_col10 {
#             background-color:  yellow;
#         }</style><table id="T_3337c6f8_3f96_11ea_81f9_0242ac110004" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ts_uts</th>        <th class="col_heading level0 col1" >endts_uts</th>        <th class="col_heading level0 col2" >type</th>        <th class="col_heading level0 col3" >opflags</th>        <th class="col_heading level0 col4" >proc.pid</th>        <th class="col_heading level0 col5" >proc.tid</th>        <th class="col_heading level0 col6" >proc.exe</th>        <th class="col_heading level0 col7" >file.path</th>        <th class="col_heading level0 col8" >flow.rbytes</th>        <th class="col_heading level0 col9" >flow.wbytes</th>        <th class="col_heading level0 col10" >container.imageid</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3337c6f8_3f96_11ea_81f9_0242ac110004level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3337c6f8_3f96_11ea_81f9_0242ac110004row0_col0" class="data row0 col0" >1531776715030353952</td>
#                         <td id="T_3337c6f8_3f96_11ea_81f9_0242ac110004row0_col1" class="data row0 col1" >1531776715030578781</td>
#                         <td id="T_3337c6f8_3f96_11ea_81f9_0242ac110004row0_col2" class="data row0 col2" >FF</td>
#                         <td id="T_3337c6f8_3f96_11ea_81f9_0242ac110004row0_col3" class="data row0 col3" >   W     T </td>
#                         <td id="T_3337c6f8_3f96_11ea_81f9_0242ac110004row0_col4" class="data row0 col4" >2025</td>
#                         <td id="T_3337c6f8_3f96_11ea_81f9_0242ac110004row0_col5" class="data row0 col5" >12406</td>
#                         <td id="T_3337c6f8_3f96_11ea_81f9_0242ac110004row0_col6" class="data row0 col6" >/usr/local/bin/node</td>
#                         <td id="T_3337c6f8_3f96_11ea_81f9_0242ac110004row0_col7" class="data row0 col7" >/tmp/exfil.py</td>
#                         <td id="T_3337c6f8_3f96_11ea_81f9_0242ac110004row0_col8" class="data row0 col8" >0</td>
#                         <td id="T_3337c6f8_3f96_11ea_81f9_0242ac110004row0_col9" class="data row0 col9" >6537</td>
#                         <td id="T_3337c6f8_3f96_11ea_81f9_0242ac110004row0_col10" class="data row0 col10" >55f142ac5da7d234c7bba0662149e26bada9c6baaf504f632e13c840206fab7b</td>
#             </tr>
#     </tbody></table>

# %%
# Policies can also be defined and reused
reader = FlattenedSFReader(trace)
formatter = SFFormatter(reader, defs=['sfql/defs.yaml'])
df = formatter.toDataframe(expr='suspicious_webserver_writes', fields=cols)
df.style.apply(highlight_path, axis=1)
# Out:
# <style  type="text/css" >
#     #T_3486d2f6_3f96_11ea_81f9_0242ac110004row0_col0 {
#             background-color:  yellow;
#         }    #T_3486d2f6_3f96_11ea_81f9_0242ac110004row0_col1 {
#             background-color:  yellow;
#         }    #T_3486d2f6_3f96_11ea_81f9_0242ac110004row0_col2 {
#             background-color:  yellow;
#         }    #T_3486d2f6_3f96_11ea_81f9_0242ac110004row0_col3 {
#             background-color:  yellow;
#         }    #T_3486d2f6_3f96_11ea_81f9_0242ac110004row0_col4 {
#             background-color:  yellow;
#         }    #T_3486d2f6_3f96_11ea_81f9_0242ac110004row0_col5 {
#             background-color:  yellow;
#         }    #T_3486d2f6_3f96_11ea_81f9_0242ac110004row0_col6 {
#             background-color:  yellow;
#         }    #T_3486d2f6_3f96_11ea_81f9_0242ac110004row0_col7 {
#             background-color:  yellow;
#         }    #T_3486d2f6_3f96_11ea_81f9_0242ac110004row0_col8 {
#             background-color:  yellow;
#         }    #T_3486d2f6_3f96_11ea_81f9_0242ac110004row0_col9 {
#             background-color:  yellow;
#         }    #T_3486d2f6_3f96_11ea_81f9_0242ac110004row0_col10 {
#             background-color:  yellow;
#         }</style><table id="T_3486d2f6_3f96_11ea_81f9_0242ac110004" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ts_uts</th>        <th class="col_heading level0 col1" >endts_uts</th>        <th class="col_heading level0 col2" >type</th>        <th class="col_heading level0 col3" >opflags</th>        <th class="col_heading level0 col4" >proc.pid</th>        <th class="col_heading level0 col5" >proc.tid</th>        <th class="col_heading level0 col6" >proc.exe</th>        <th class="col_heading level0 col7" >file.path</th>        <th class="col_heading level0 col8" >flow.rbytes</th>        <th class="col_heading level0 col9" >flow.wbytes</th>        <th class="col_heading level0 col10" >container.imageid</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3486d2f6_3f96_11ea_81f9_0242ac110004level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3486d2f6_3f96_11ea_81f9_0242ac110004row0_col0" class="data row0 col0" >1531776715030353952</td>
#                         <td id="T_3486d2f6_3f96_11ea_81f9_0242ac110004row0_col1" class="data row0 col1" >1531776715030578781</td>
#                         <td id="T_3486d2f6_3f96_11ea_81f9_0242ac110004row0_col2" class="data row0 col2" >FF</td>
#                         <td id="T_3486d2f6_3f96_11ea_81f9_0242ac110004row0_col3" class="data row0 col3" >   W     T </td>
#                         <td id="T_3486d2f6_3f96_11ea_81f9_0242ac110004row0_col4" class="data row0 col4" >2025</td>
#                         <td id="T_3486d2f6_3f96_11ea_81f9_0242ac110004row0_col5" class="data row0 col5" >12406</td>
#                         <td id="T_3486d2f6_3f96_11ea_81f9_0242ac110004row0_col6" class="data row0 col6" >/usr/local/bin/node</td>
#                         <td id="T_3486d2f6_3f96_11ea_81f9_0242ac110004row0_col7" class="data row0 col7" >/tmp/exfil.py</td>
#                         <td id="T_3486d2f6_3f96_11ea_81f9_0242ac110004row0_col8" class="data row0 col8" >0</td>
#                         <td id="T_3486d2f6_3f96_11ea_81f9_0242ac110004row0_col9" class="data row0 col9" >6537</td>
#                         <td id="T_3486d2f6_3f96_11ea_81f9_0242ac110004row0_col10" class="data row0 col10" >55f142ac5da7d234c7bba0662149e26bada9c6baaf504f632e13c840206fab7b</td>
#             </tr>
#     </tbody></table>

# %%
trace = 'data/attacks/express/mon.1531776712.sf'
cols_=['ts_uts', 'type', 'opflags', 'pproc.pid', 'proc.pid', 'pproc.exe',  'proc.exe', 'proc.args']

# %%
# Finding all process executions involving suspicious script
reader = FlattenedSFReader(trace)
query = 'type = PE and opflags = EXEC and (proc.aname contains exfil.py or proc.args contains exfil.py or file.path contains exfil.py)'
formatter = SFFormatter(reader)
df = formatter.toDataframe(expr=query, fields=cols_)
df.head(20)
# Out:
#                  ts_uts type opflags  pproc.pid  proc.pid  \
# 0   1531776715041743005   PE    EXEC       2025     17753
# 1   1531776715049024767   PE    EXEC      17753     17754
# 2   1531776715077890260   PE    EXEC      17754     17757
# 3   1531776715078056634   PE    EXEC      17754     17757
# 4   1531776715078110412   PE    EXEC      17754     17757
# 5   1531776715078162793   PE    EXEC      17754     17757
# 6   1531776715078210871   PE    EXEC      17754     17757
# 7   1531776715078687969   PE    EXEC      17754     17757
# 8   1531776716574185341   PE    EXEC      17757     17758
# 9   1531776718037729035   PE    EXEC      17757     17767
# 10  1531776721816616574   PE    EXEC      13526     17819
# 11  1531776724236565898   PE    EXEC      17757     17826
# 12  1531776735465803137   PE    EXEC      17757     18005
# 13  1531776738136774803   PE    EXEC      17757     18043
# 14  1531776738141911192   PE    EXEC      17754     18062
# 15  1531776738142131579   PE    EXEC      17754     18062
# 16  1531776738142187946   PE    EXEC      17754     18062
# 17  1531776738142269667   PE    EXEC      17754     18062
# 18  1531776738142313320   PE    EXEC      17754     18062
# 19  1531776738142823237   PE    EXEC      17754     18062
#
#               pproc.exe                   proc.exe  \
# 0   /usr/local/bin/node                    /bin/sh
# 1               /bin/sh              /tmp/exfil.py
# 2         /tmp/exfil.py              /tmp/exfil.py
# 3         /tmp/exfil.py              /tmp/exfil.py
# 4         /tmp/exfil.py              /tmp/exfil.py
# 5         /tmp/exfil.py              /tmp/exfil.py
# 6         /tmp/exfil.py              /tmp/exfil.py
# 7         /tmp/exfil.py           /usr/bin/apt-get
# 8      /usr/bin/apt-get           /usr/bin/apt-get
# 9      /usr/bin/apt-get           /usr/bin/apt-get
# 10            /bin/bash                  /bin/more
# 11     /usr/bin/apt-get  /usr/lib/apt/methods/gpgv
# 12     /usr/bin/apt-get              /usr/bin/dpkg
# 13     /usr/bin/apt-get              /usr/bin/dpkg
# 14        /tmp/exfil.py              /tmp/exfil.py
# 15        /tmp/exfil.py              /tmp/exfil.py
# 16        /tmp/exfil.py              /tmp/exfil.py
# 17        /tmp/exfil.py              /tmp/exfil.py
# 18        /tmp/exfil.py              /tmp/exfil.py
# 19        /tmp/exfil.py           /usr/bin/apt-get
#
#                         proc.args
# 0             -c /tmp/exfil.py -a
# 1                /tmp/exfil.py -a
# 2                /tmp/exfil.py -a
# 3                /tmp/exfil.py -a
# 4                /tmp/exfil.py -a
# 5                /tmp/exfil.py -a
# 6                /tmp/exfil.py -a
# 7                          update
# 8   --print-foreign-architectures
# 9
# 10                       exfil.py
# 11
# 12  --print-foreign-architectures
# 13  --print-foreign-architectures
# 14               /tmp/exfil.py -a
# 15               /tmp/exfil.py -a
# 16               /tmp/exfil.py -a
# 17               /tmp/exfil.py -a
# 18               /tmp/exfil.py -a
# 19          install -y python-pip

# %%
_trace = 'data/attacks/express/mon.1531776742.sf'
_cols=['ts_uts', 'type', 'opflags', 'proc.pid', 'pproc.exe', 'proc.exe', 'proc.args', 'net.sip', 'net.sport', 'net.dip', 'net.dport', 'flow.rbytes', 'flow.wbytes']

# %%
def highlight_ip(r):
    if r['net.dip'].startswith('104'):
        return ['background-color: yellow'] * len(_cols)
    if r['net.dip'].startswith('158'):
        return ['background-color: cyan'] * len(_cols)
    return [''] * len(_cols)

# %%
# Finding all network flows related to suspicious script
reader = FlattenedSFReader(_trace)
query = 'type = NF and (proc.aname contains exfil.py or proc.args contains exfil.py or file.path contains exfil.py)'
formatter = SFFormatter(reader)
df = formatter.toDataframe(expr=query, fields=_cols)
df.style.apply(highlight_ip, axis=1)
# Out:
# <style  type="text/css" >
#     #T_3941efb0_3f96_11ea_81f9_0242ac110004row9_col0 {
#             background-color:  cyan;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row9_col1 {
#             background-color:  cyan;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row9_col2 {
#             background-color:  cyan;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row9_col3 {
#             background-color:  cyan;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row9_col4 {
#             background-color:  cyan;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row9_col5 {
#             background-color:  cyan;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row9_col6 {
#             background-color:  cyan;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row9_col7 {
#             background-color:  cyan;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row9_col8 {
#             background-color:  cyan;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row9_col9 {
#             background-color:  cyan;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row9_col10 {
#             background-color:  cyan;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row9_col11 {
#             background-color:  cyan;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row9_col12 {
#             background-color:  cyan;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row18_col0 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row18_col1 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row18_col2 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row18_col3 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row18_col4 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row18_col5 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row18_col6 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row18_col7 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row18_col8 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row18_col9 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row18_col10 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row18_col11 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row18_col12 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row19_col0 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row19_col1 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row19_col2 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row19_col3 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row19_col4 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row19_col5 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row19_col6 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row19_col7 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row19_col8 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row19_col9 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row19_col10 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row19_col11 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row19_col12 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row24_col0 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row24_col1 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row24_col2 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row24_col3 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row24_col4 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row24_col5 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row24_col6 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row24_col7 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row24_col8 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row24_col9 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row24_col10 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row24_col11 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row24_col12 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row25_col0 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row25_col1 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row25_col2 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row25_col3 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row25_col4 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row25_col5 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row25_col6 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row25_col7 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row25_col8 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row25_col9 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row25_col10 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row25_col11 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row25_col12 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row30_col0 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row30_col1 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row30_col2 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row30_col3 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row30_col4 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row30_col5 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row30_col6 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row30_col7 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row30_col8 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row30_col9 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row30_col10 {
#             background-color:  yellow;
#         }    #T_3941efb0_3f96_11ea_81f9_0242ac110004row30_col11 {
#             background-color:  yello

# %%
# Summarizing sysflow types
reader = FlattenedSFReader(trace)
formatter = SFFormatter(reader)
df = formatter.toDataframe(fields=cols)
types = df.groupby(['type']).count()[['ts_uts']].rename(columns={"ts_uts": "count"}) 
types
# Out:
#       count
# type
# FE        3
# FF     6002
# NF       86
# PE      234

# %%
pie = types.plot.pie(subplots=True)

# %%
# Rank ordering file operations
_df = df.replace('', np.nan).dropna(axis=0, how='any', subset=['file.path'])
paths = _df[cols].groupby(['file.path']).count()[['ts_uts']].rename(columns={"ts_uts": "count"})
paths.sort_values(by='count', ascending=False)
# Out:
#                                                                          count
# file.path
# /etc/ld.so.cache                                                            96
# /lib/x86_64-linux-gnu/libc.so.6                                             48
# /dev/null                                                                   20
# pipe:[66729332]                                                             18
# /etc/hosts                                                                  16
# ...                                                                        ...
# /var/lib/apt/lists/lock                                                      1
# /etc/services                                                                1
# /etc/apt/sources.list.d                                                      1
# /var/lib/apt/lists/deb.debian.org_debian_dists_jessie-updates_InRelease      1
# /tmp/malware.log                                                             1
#
# [915 rows x 1 columns]

# %%
pie = paths.sort_values(by='count', ascending=False).head(25).plot.pie(subplots=True, figsize=(9, 6), legend=None)

# %%
pie = paths.sort_values(by='count', ascending=False).tail(25).plot.pie(subplots=True, figsize=(9, 6), legend=None)
